# %% [markdown]
# ## 1. 定义算法
#
# NoisyDQN 是在 DQN 的基础上进行改进，主要就是通过在训练网络的时候加上一些噪声参数，可以用较小的额外计算成本，在强化学习算法上获得更优的结果。
# 配置和 DQN 基本一致，只是在模型定义的时候，在模型中加入了一些噪声参数。

# %% [markdown]
# ### 1.1、 定义模型
# 这里使用了一个三层的MLP，不同的是其中加入了一些噪声参数，就是每个权值weight和偏置bias中都有额外的参数mu和sigma，这里仅供参考。

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
class NoisyLinear(nn.Module):
    def __init__(self, input_dim, output_dim, std_init=0.4):
        super(NoisyLinear, self).__init__()
        
        self.input_dim  = input_dim
        self.output_dim = output_dim
        self.std_init     = std_init
        
        self.weight_mu    = nn.Parameter(torch.FloatTensor(output_dim, input_dim))
        self.weight_sigma = nn.Parameter(torch.FloatTensor(output_dim, input_dim))
        self.register_buffer('weight_epsilon', torch.FloatTensor(output_dim, input_dim))
        
        self.bias_mu    = nn.Parameter(torch.FloatTensor(output_dim))
        self.bias_sigma = nn.Parameter(torch.FloatTensor(output_dim))
        self.register_buffer('bias_epsilon', torch.FloatTensor(output_dim))
        
        self.reset_parameters()
        self.reset_noise()
    
    def forward(self, x):
        if self.training: 
            weight = self.weight_mu + self.weight_sigma.mul(torch.tensor(self.weight_epsilon))
            bias   = self.bias_mu   + self.bias_sigma.mul(torch.tensor(self.bias_epsilon))
        else:
            weight = self.weight_mu
            bias   = self.bias_mu
        
        return F.linear(x, weight, bias)
    
    def reset_parameters(self):
        mu_range = 1 / math.sqrt(self.weight_mu.size(1))
        
        self.weight_mu.data.uniform_(-mu_range, mu_range)
        self.weight_sigma.data.fill_(self.std_init / math.sqrt(self.weight_sigma.size(1)))
        
        self.bias_mu.data.uniform_(-mu_range, mu_range)
        self.bias_sigma.data.fill_(self.std_init / math.sqrt(self.bias_sigma.size(0)))
    
    def reset_noise(self):
        epsilon_in  = self._scale_noise(self.input_dim)
        epsilon_out = self._scale_noise(self.output_dim)
        
        self.weight_epsilon.copy_(epsilon_out.ger(epsilon_in))
        self.bias_epsilon.copy_(self._scale_noise(self.output_dim))
    
    def _scale_noise(self, size):
        x = torch.randn(size)
        x = x.sign().mul(x.abs().sqrt())
        return x

class NoisyMLP(nn.Module):
    def __init__(self, input_dim,output_dim,hidden_dim=128):
        super(NoisyMLP, self).__init__()
        self.fc1 =  nn.Linear(input_dim, hidden_dim)
        self.noisy_fc2 = NoisyLinear(hidden_dim, hidden_dim)
        self.noisy_fc3 = NoisyLinear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.noisy_fc2(x))
        x = self.noisy_fc3(x)
        return x

    def reset_noise(self):
        self.noisy_fc2.reset_noise()
        self.noisy_fc3.reset_noise()

# %% [markdown]
# ### 1.2、定义经验回放
#
# 这里的经验回放和DQN中保持一致，也是具有一定容量，只有存储到一定的transition网络才会更新。经验回放的时候一般包涵两个功能或方法，一个是push，即将一个transition样本按顺序放到经验回放中，如果满了就把最开始放进去的样本挤掉；另外一个是sample，就是随机采样出一个或者若干个（具体多少就是batch_size了）样本供DQN网络更新。

# %%
from collections import deque
import random
class ReplayBuffer(object):
    def __init__(self, capacity: int) -> None:
        self.capacity = capacity
        self.buffer = deque(maxlen=self.capacity)
    def push(self,transitions):
        ''' 存储transition到经验回放中
        '''
        self.buffer.append(transitions)
    def sample(self, batch_size: int, sequential: bool = False):
        if batch_size > len(self.buffer): # 如果批量大小大于经验回放的容量，则取经验回放的容量
            batch_size = len(self.buffer)
        if sequential: # 顺序采样
            rand = random.randint(0, len(self.buffer) - batch_size)
            batch = [self.buffer[i] for i in range(rand, rand + batch_size)]
            return zip(*batch)
        else: # 随机采样
            batch = random.sample(self.buffer, batch_size)
            return zip(*batch)
    def clear(self):
        ''' 清空经验回放
        '''
        self.buffer.clear()
    def __len__(self):
        ''' 返回当前存储的量
        '''
        return len(self.buffer)

# %% [markdown]
# ### 1.3、模型算法定义
#
# 这里根据前面的噪声MLP搭建智能体agent，其中的动作采样和模型更新和DQN基本一致，这里不再赘述。

# %%
import torch
import torch.optim as optim
import math
import numpy as np

class NoisyDQN:
    def __init__(self, model, memory, cfg) -> None:
        self.n_actions = cfg.n_actions  
        self.device = torch.device(cfg.device) 
        self.gamma = cfg.gamma  
        ## e-greedy策略相关参数
        self.sample_count = 0  # 用于epsilon的衰减计数
        self.epsilon = cfg.epsilon_start
        self.epsilon_start = cfg.epsilon_start
        self.epsilon_end = cfg.epsilon_end
        self.epsilon_decay = cfg.epsilon_decay
        self.batch_size = cfg.batch_size
        self.target_update = cfg.target_update

        self.device = torch.device(cfg.device) 

        self.policy_net = model.to(self.device)
        self.target_net = model.to(self.device)
        ## 复制参数到目标网络
        for target_param, param in zip(self.target_net.parameters(),self.policy_net.parameters()): 
            target_param.data.copy_(param.data)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=cfg.lr)
        self.memory = memory ## 经验回放
        self.update_flag = False
        
    def sample_action(self, state):
        ''' sample action with e-greedy policy 
        '''
        self.sample_count += 1
        # epsilon 指数衰减
        self.epsilon = self.epsilon_end + (self.epsilon_start - self.epsilon_end) * \
            math.exp(-1. * self.sample_count / self.epsilon_decay) 
        if random.random() > self.epsilon:
            with torch.no_grad():
                state = torch.tensor(state, device=self.device, dtype=torch.float32).unsqueeze(dim=0)
                q_values = self.policy_net(state)
                action = q_values.max(1)[1].item() # 根据Q值选择动作
        else:
            action = random.randrange(self.n_actions)
        return action

    @torch.no_grad()
    def predict_action(self, state):
        state = torch.tensor(state, device=self.device, dtype=torch.float32).unsqueeze(dim=0)
        q_value = self.policy_net(state)
        action  = q_value.max(1)[1].item()
        return action
    def update(self):
        if len(self.memory) < self.batch_size: # 不满足一个批量时，不更新策略
            return
        else:
            if not self.update_flag:
                print("Begin to update!")
                self.update_flag = True
        # beta = min(1.0, self.beta_start + self.sample_count * (1.0 - self.beta_start) / self.beta_frames)
        state_batch, action_batch, reward_batch, next_state_batch, done_batch = self.memory.sample(
            self.batch_size)
        # state_batch, action_batch, reward_batch, next_state_batch, done_batch, weights_batch, indices = self.memory.sample(self.batch_size, beta) 
        state_batch = torch.tensor(np.array(state_batch), device=self.device, dtype=torch.float) 
        action_batch = torch.tensor(action_batch, device=self.device).unsqueeze(1)
        reward_batch = torch.tensor(reward_batch, device=self.device, dtype=torch.float).unsqueeze(1)
        next_state_batch = torch.tensor(np.array(next_state_batch), device=self.device, dtype=torch.float) # shape(batchsize,n_states)
        done_batch = torch.tensor(done_batch, device=self.device, dtype=torch.float).unsqueeze(1)
        # weights_batch = torch.tensor(weights_batch, device=self.device, dtype=torch.float)

        q_value_batch = self.policy_net(state_batch).gather(dim=1, index=action_batch) # shape(batchsize,1),requires_grad=True
        next_max_q_value_batch = self.target_net(next_state_batch).max(1)[0].detach().unsqueeze(1) 
        expected_q_value_batch = reward_batch + self.gamma * next_max_q_value_batch* (1-done_batch)

        loss = nn.MSELoss()(q_value_batch, expected_q_value_batch)  # shape same to  
        # 反向传播
        self.optimizer.zero_grad()  
        loss.backward()
        # 梯度截断，防止梯度爆炸
        for param in self.policy_net.parameters():  
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step() 

        if self.sample_count % self.target_update == 0: # 更新 target_net
            self.target_net.load_state_dict(self.policy_net.state_dict())   

        ## 噪声参数重置
        self.policy_net.reset_noise()
        self.target_net.reset_noise()

# %% [markdown]
# ## 2、 定义训练

# %%
def train(cfg, env, agent):
    ''' 训练
    '''
    print("开始训练！")
    rewards = []  # 记录所有回合的奖励
    steps = []
    for i_ep in range(cfg.train_eps):
        ep_reward = 0  # 记录一回合内的奖励
        ep_step = 0
        state = env.reset()  # 重置环境，返回初始状态
        for _ in range(cfg.max_steps):
            ep_step += 1
            action = agent.sample_action(state)  # 选择动作
            next_state, reward, done, _ = env.step(action)  # 更新环境，返回transition
            agent.memory.push((state, action, reward,next_state, done))  # 保存transition
            state = next_state  # 更新下一个状态
            agent.update()  # 更新智能体
            ep_reward += reward  # 累加奖励
            if done:
                break
        if (i_ep + 1) % cfg.target_update == 0:  # 智能体目标网络更新
            agent.target_net.load_state_dict(agent.policy_net.state_dict())
        steps.append(ep_step)
        rewards.append(ep_reward)
        if (i_ep + 1) % 10 == 0:
            print(f"回合：{i_ep+1}/{cfg.train_eps}，奖励：{ep_reward:.2f}，Epislon：{agent.epsilon:.3f}")
    print("完成训练！")
    env.close()
    return {'rewards':rewards}

def test(cfg, env, agent):
    print("开始测试！")
    rewards = []  # 记录所有回合的奖励
    steps = []
    for i_ep in range(cfg.test_eps):
        ep_reward = 0  # 记录一回合内的奖励
        ep_step = 0
        state = env.reset()  # 重置环境，返回初始状态
        for _ in range(cfg.max_steps):
            ep_step+=1
            action = agent.predict_action(state)  # 选择动作
            next_state, reward, done, _ = env.step(action)  # 更新环境，返回transition
            state = next_state  # 更新下一个状态
            ep_reward += reward  # 累加奖励
            if done:
                break
        steps.append(ep_step)
        rewards.append(ep_reward)
        print(f"回合：{i_ep+1}/{cfg.test_eps}，奖励：{ep_reward:.2f}")
    print("完成测试")
    env.close()
    return {'rewards':rewards}

# %% [markdown]
# ## 3. 定义环境

# %%
import gym
import os
def all_seed(env,seed = 1):
    ''' 万能的seed函数
    '''
    env.seed(seed) # env config
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed) # config for CPU
    torch.cuda.manual_seed(seed) # config for GPU
    os.environ['PYTHONHASHSEED'] = str(seed) # config for python scripts
    # config for cudnn
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.enabled = False
def env_agent_config(cfg):
    env = gym.make(cfg.env_name) # 创建环境
    if cfg.seed !=0:
        all_seed(env,seed=cfg.seed)
    n_states = env.observation_space.shape[0]
    n_actions = env.action_space.n
    print(f"状态空间维度：{n_states}，动作空间维度：{n_actions}")

    cfg.n_actions = env.action_space.n  ## set the env action space
    model = NoisyMLP(n_states, n_actions, hidden_dim = cfg.hidden_dim) # 创建模型
    memory = ReplayBuffer(cfg.buffer_size)
    agent = NoisyDQN(model,memory,cfg)
    return env,agent
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 4、设置参数

# %%
import argparse
import matplotlib.pyplot as plt
import seaborn as sns
class Config():
    def __init__(self) -> None:
        self.env_name = "CartPole-v1" # 环境名字
        self.new_step_api = True # 是否用gym的新api
        self.wrapper = None 
        self.render = False 
        self.algo_name = "NoisyDQN" # 算法名字
        self.mode = "train" # train or test
        self.seed = 0 # 随机种子
        self.device = "cpu" # device to use
        self.train_eps = 5000 # 训练的回合数
        self.test_eps = 20 # 测试的回合数
        self.eval_eps = 10 # 评估的回合数
        self.eval_per_episode = 20 # 每个回合的评估次数
        self.max_steps = 500 # 每个回合的最大步数
        self.load_checkpoint = False
        self.load_path = "tasks" # 加载模型的路径
        self.show_fig = False # 是否展示图片
        self.save_fig = True # 是否存储图片


        # 设置epsilon值
        self.epsilon_start = 0.95 # 起始的epsilon值
        self.epsilon_end = 0.01 # 终止的epsilon值
        self.epsilon_decay = 500 # 衰减率
        self.hidden_dim = 256 
        self.gamma = 0.95 
        self.lr = 0.0001 
        self.buffer_size = 100000 # 经验回放的buffer大小
        self.batch_size = 64 # batch size
        self.target_update = 4 # 目标网络更新频率
        self.value_layers = [
            {'layer_type': 'linear', 'layer_dim': ['n_states', 256],
             'activation': 'relu'},
            {'layer_type': 'linear', 'layer_dim': [256, 256],
             'activation': 'relu'},
            {'layer_type': 'linear', 'layer_dim': [256, 'n_actions'],
             'activation': 'none'}]

def smooth(data, weight=0.9):  
    '''用于平滑曲线，类似于Tensorboard中的smooth曲线
    '''
    last = data[0] 
    smoothed = []
    for point in data:
        smoothed_val = last * weight + (1 - weight) * point  # 计算平滑值
        smoothed.append(smoothed_val)                    
        last = smoothed_val                                
    return smoothed

def plot_rewards(rewards,cfg, tag='train'):
    ''' 画图
    '''
    sns.set()
    plt.figure()  # 创建一个图形实例，方便同时多画几个图
    plt.title(f"{tag}ing curve on {cfg.device} of {cfg.algo_name} for {cfg.env_name}")
    plt.xlabel('epsiodes')
    plt.plot(rewards, label='rewards')
    plt.plot(smooth(rewards), label='smoothed')
    plt.legend()
    plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 5、开始训练

# %%
# 获取参数
cfg = Config() 
# 训练
env, agent = env_agent_config(cfg)
res_dic = train(cfg, env, agent)
 
plot_rewards(res_dic['rewards'], cfg, tag="train")  
# 测试
res_dic = test(cfg, env, agent)
plot_rewards(res_dic['rewards'], cfg, tag="test")  # 画出结果
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/lib/python3.12/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/lib/python3.12/site-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 状态空间维度：4，动作空间维度：2
# 开始训练！
# Begin to update!
# 回合：10/5000，奖励：12.00，Epislon：0.690
# /opt/anaconda3/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# /var/folders/rc/4jr_8mlj2ng1hg4rbf4lzk1w0000gn/T/ipykernel_5612/2015173130.py:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weight = self.weight_mu + self.weight_sigma.mul(torch.tensor(self.weight_epsilon))
# /var/folders/rc/4jr_8mlj2ng1hg4rbf4lzk1w0000gn/T/ipykernel_5612/2015173130.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   bias   = self.bias_mu   + self.bias_sigma.mul(torch.tensor(self.bias_epsilon))
# 回合：20/5000，奖励：40.00，Epislon：0.471
# 回合：30/5000，奖励：11.00，Epislon：0.347
# 回合：40/5000，奖励：33.00，Epislon：0.226
# 回合：50/5000，奖励：53.00，Epislon：0.100
# 回合：60/5000，奖励：260.00，Epislon：0.023
# 回合：70/5000，奖励：280.00，Epislon：0.010
# 回合：80/5000，奖励：262.00，Epislon：0.010
# 回合：90/5000，奖励：271.00，Epislon：0.010
# 回合：100/5000，奖励：236.00，Epislon：0.010
# 回合：110/5000，奖励：274.00，Epislon：0.010
# 回合：120/5000，奖励：289.00，Epislon：0.010
# 回合：130/5000，奖励：296.00，Epislon：0.010
# 回合：140/5000，奖励：290.00，Epislon：0.010
# 回合：150/5000，奖励：296.00，Epislon：0.010
# 回合：160/5000，奖励：272.00，Epislon：0.010
# 回合：170/5000，奖励：500.00，Epislon：0.010
# 回合：180/5000，奖励：500.00，Epislon：0.010
# 回合：190/5000，奖励：330.00，Epislon：0.010
# 回合：200/5000，奖励：299.00，Epislon：0.010
# 回合：210/5000，奖励：178.00，Epislon：0.010
# 回合：220/5000，奖励：203.00，Epislon：0.010
# 回合：230/5000，奖励：153.00，Epislon：0.010
# 回合：240/5000，奖励：141.00，Epislon：0.010
# 回合：250/5000，奖励：173.00，Epislon：0.010
# 回合：260/5000，奖励：159.00，Epislon：0.010
# 回合：270/5000，奖励：154.00，Epislon：0.010
# 回合：280/5000，奖励：156.00，Epislon：0.010
# 回合：290/5000，奖励：192.00，Epislon：0.010
# 回合：300/5000，奖励：181.00，Epislon：0.010
# 回合：310/5000，奖励：209.00，Epislon：0.010
# 回合：320/5000，奖励：221.00，Epislon：0.010
# 回合：330/5000，奖励：305.00，Epislon：0.010
# 回合：340/5000，奖励：195.00，Epislon：0.010
# 回合：350/5000，奖励：171.00，Epislon：0.010
# 回合：360/5000，奖励：189.00，Epislon：0.010
# 回合：370/5000，奖励：171.00，Epislon：0.010
# 回合：380/5000，奖励：260.00，Epislon：0.010
# 回合：390/5000，奖励：352.00，Epislon：0.010
# 回合：400/5000，奖励：239.00，Epislon：0.010
# 回合：410/5000，奖励：191.00，Epislon：0.010
# 回合：420/5000，奖励：252.00，Epislon：0.010
# 回合：430/5000，奖励：167.00，Epislon：0.010
# 回合：440/5000，奖励：206.00，Epislon：0.010
# 回合：450/5000，奖励：192.00，Epislon：0.010
# 回合：460/5000，奖励：240.00，Epislon：0.010
# 回合：470/5000，奖励：196.00，Epislon：0.010
# 回合：480/5000，奖励：221.00，Epislon：0.010
# 回合：490/5000，奖励：256.00，Epislon：0.010
# 回合：500/5000，奖励：257.00，Epislon：0.010
# 回合：510/5000，奖励：200.00，Epislon：0.010
# 回合：520/5000，奖励：216.00，Epislon：0.010
# 回合：530/5000，奖励：206.00，Epislon：0.010
# 回合：540/5000，奖励：233.00，Epislon：0.010
# 回合：550/5000，奖励：189.00，Epislon：0.010
# 回合：560/5000，奖励：234.00，Epislon：0.010
# 回合：570/5000，奖励：228.00，Epislon：0.010
# 回合：580/5000，奖励：224.00，Epislon：0.010
# 回合：590/5000，奖励：265.00，Epislon：0.010
# 回合：600/5000，奖励：196.00，Epislon：0.010
# 回合：610/5000，奖励：232.00，Epislon：0.010
# 回合：620/5000，奖励：277.00，Epislon：0.010
# 回合：630/5000，奖励：323.00，Epislon：0.010
# 回合：640/5000，奖励：500.00，Epislon：0.010
# 回合：650/5000，奖励：500.00，Epislon：0.010
# 回合：660/5000，奖励：210.00，Epislon：0.010
# 回合：670/5000，奖励：381.00，Epislon：0.010
# 回合：680/5000，奖励：500.00，Epislon：0.010
# 回合：690/5000，奖励：500.00，Epislon：0.010
# 回合：700/5000，奖励：500.00，Epislon：0.010
# 回合：710/5000，奖励：418.00，Epislon：0.010
# 回合：720/5000，奖励：356.00，Epislon：0.010
# 回合：730/5000，奖励：245.00，Epislon：0.010
# 回合：740/5000，奖励：492.00，Epislon：0.010
# 回合：750/5000，奖励：199.00，Epislon：0.010
# 回合：760/5000，奖励：208.00，Epislon：0.010
# 回合：770/5000，奖励：219.00，Epislon：0.010
# 回合：780/5000，奖励：60.00，Epislon：0.010
# 回合：790/5000，奖励：250.00，Epislon：0.010
# 回合：800/5000，奖励：500.00，Epislon：0.010
# 回合：810/5000，奖励：183.00，Epislon：0.010
# 回合：820/5000，奖励：500.00，Epislon：0.010
# 回合：830/5000，奖励：500.00，Epislon：0.010
# 回合：840/5000，奖励：177.00，Epislon：0.010
# 回合：850/5000，奖励：500.00，Epislon：0.010
# 回合：860/5000，奖励：329.00，Epislon：0.010
# 回合：870/5000，奖励：500.00，Epislon：0.010
# 回合：880/5000，奖励：183.00，Epislon：0.010
# 回合：890/5000，奖励：500.00，Epislon：0.010
# 回合：900/5000，奖励：494.00，Epislon：0.010
# 回合：910/5000，奖励：500.00，Epislon：0.010
# 回合：920/5000，奖励：500.00，Epislon：0.010
# 回合：930/5000，奖励：226.00，Epislon：0.010
# 回合：940/5000，奖励：314.00，Epislon：0.010
# 回合：950/5000，奖励：197.00，Epislon：0.010
# 回合：960/5000，奖励：169.00，Epislon：0.010
# 回合：970/5000，奖励：146.00，Epislon：0.010
# 回合：980/5000，奖励：13.00，Epislon：0.010
# 回合：990/5000，奖励：265.00，Epislon：0.010
# 回合：1000/5000，奖励：500.00，Epislon：0.010
# 回合：1010/5000，奖励：500.00，Epislon：0.010
# 回合：1020/5000，奖励：500.00，Epislon：0.010
# 回合：1030/5000，奖励：429.00，Epislon：0.010
# 回合：1040/5000，奖励：489.00，Epislon：0.010
# 回合：1050/5000，奖励：500.00，Epislon：0.010
# 回合：1060/5000，奖励：339.00，Epislon：0.010
# 回合：1070/5000，奖励：500.00，Epislon：0.010
# 回合：1080/5000，奖励：246.00，Epislon：0.010
# 回合：1090/5000，奖励：500.00，Epislon：0.010
# 回合：1100/5000，奖励：241.00，Epislon：0.010
# 回合：1110/5000，奖励：375.00，Epislon：0.010
# 回合：1120/5000，奖励：224.00，Epislon：0.010
# 回合：1130/5000，奖励：219.00，Epislon：0.010
# 回合：1140/5000，奖励：170.00，Epislon：0.010
# 回合：1150/5000，奖励：183.00，Epislon：0.010
# 回合：1160/5000，奖励：500.00，Epislon：0.010
# 回合：1170/5000，奖励：292.00，Epislon：0.010
# 回合：1180/5000，奖励：73.00，Epislon：0.010
# 回合：1190/5000，奖励：189.00，Epislon：0.010
# 回合：1200/5000，奖励：500.00，Epislon：0.010
# 回合：1210/5000，奖励：246.00，Epislon：0.010
# 回合：1220/5000，奖励：192.00，Epislon：0.010
# 回合：1230/5000，奖励：396.00，Epislon：0.010
# 回合：1240/5000，奖励：230.00，Epislon：0.010
# 回合：1250/5000，奖励：300.00，Epislon：0.010
# 回合：1260/5000，奖励：206.00，Epislon：0.010
# 回合：1270/5000，奖励：500.00，Epislon：0.010
# 回合：1280/5000，奖励：500.00，Epislon：0.010
# 回合：1290/5000，奖励：500.00，Epislon：0.010
# 回合：1300/5000，奖励：416.00，Epislon：0.010
# 回合：1310/5000，奖励：500.00，Epislon：0.010
# 回合：1320/5000，奖励：500.00，Epislon：0.010
# 回合：1330/5000，奖励：500.00，Epislon：0.010
# 回合：1340/5000，奖励：500.00，Epislon：0.010
# 回合：1350/5000，奖励：500.00，Epislon：0.010
# 回合：1360/5000，奖励：500.00，Epislon：0.010
# 回合：1370/5000，奖励：500.00，Epislon：0.010
# 回合：1380/5000，奖励：500.00，Epislon：0.010
# 回合：1390/5000，奖励：500.00，Epislon：0.010
# 回合：1400/5000，奖励：331.00，Epislon：0.010
# 回合：1410/5000，奖励：258.00，Epislon：0.010
# 回合：1420/5000，奖励：500.00，Epislon：0.010
# 回合：1430/5000，奖励：500.00，Epislon：0.010
# 回合：1440/5000，奖励：312.00，Epislon：0.010
# 回合：1450/5000，奖励：500.00，Epislon：0.010
# 回合：1460/5000，奖励：131.00，Epislon：0.010
# 回合：1470/5000，奖励：500.00，Epislon：0.010
# 回合：1480/5000，奖励：397.00，Epislon：0.010
# 回合：1490/5000，奖励：403.00，Epislon：0.010
# 回合：1500/5000，奖励：500.00，Epislon：0.010
# 回合：1510/5000，奖励：59.00，Epislon：0.010
# 回合：1520/5000，奖励：500.00，Epislon：0.010
# 回合：1530/5000，奖励：500.00，Epislon：0.010
# 回合：1540/5000，奖励：500.00，Epislon：0.010
# 回合：1550/5000，奖励：500.00，Epislon：0.010
# 回合：1560/5000，奖励：500.00，Epislon：0.010
# 回合：1570/5000，奖励：500.00，Epislon：0.010
# 回合：1580/5000，奖励：500.00，Epislon：0.010
# 回合：1590/5000，奖励：500.00，Epislon：0.010
# 回合：1600/5000，奖励：108.00，Epislon：0.010
# 回合：1610/5000，奖励：238.00，Epislon：0.010
# 回合：1620/5000，奖励：500.00，Epislon：0.010
# 回合：1630/5000，奖励：460.00，Epislon：0.010
# 回合：1640/5000，奖励：500.00，Epislon：0.010
# 回合：1650/5000，奖励：500.00，Epislon：0.010
# 回合：1660/5000，奖励：344.00，Epislon：0.010
# 回合：1670/5000，奖励：500.00，Epislon：0.010
# 回合：1680/5000，奖励：500.00，Epislon：0.010
# 回合：1690/5000，奖励：391.00，Epislon：0.010
# 回合：1700/5000，奖励：372.00，Epislon：0.010
# 回合：1710/5000，奖励：500.00，Epislon：0.010
# 回合：1720/5000，奖励：500.00，Epislon：0.010
# 回合：1730/5000，奖励：500.00，Epislon：0.010
# 回合：1740/5000，奖励：500.00，Epislon：0.010
# 回合：1750/5000，奖励：500.00，Epislon：0.010
# 回合：1760/5000，奖励：392.00，Epislon：0.010
# 回合：1770/5000，奖励：500.00，Epislon：0.010
# 回合：1780/5000，奖励：500.00，Epislon：0.010
# 回合：1790/5000，奖励：500.00，Epislon：0.010
# 回合：1800/5000，奖励：500.00，Epislon：0.010
# 回合：1810/5000，奖励：500.00，Epislon：0.010
# 回合：1820/5000，奖励：500.00，Epislon：0.010
# 回合：1830/5000，奖励：500.00，Epislon：0.010
# 回合：1840/5000，奖励：500.00，Epislon：0.010
# 回合：1850/5000，奖励：496.00，Epislon：0.010
# 回合：1860/5000，奖励：313.00，Epislon：0.010
# 回合：1870/5000，奖励：500.00，Epislon：0.010
# 回合：1880/5000，奖励：500.00，Epislon：0.010
# 回合：1890/5000，奖励：500.00，Epislon：0.010
# 回合：1900/5000，奖励：364.00，Epislon：0.010
# 回合：1910/5000，奖励：500.00，Epislon：0.010
# 回合：1920/5000，奖励：500.00，Epislon：0.010
# 回合：1930/5000，奖励：500.00，Epislon：0.010
# 回合：1940/5000，奖励：500.00，Epislon：0.010
# 回合：1950/5000，奖励：500.00，Epislon：0.010
# 回合：1960/5000，奖励：500.00，Epislon：0.010
# 回合：1970/5000，奖励：459.00，Epislon：0.010
# 回合：1980/5000，奖励：500.00，Epislon：0.010
# 回合：1990/5000，奖励：500.00，Epislon：0.010
# 回合：2000/5000，奖励：500.00，Epislon：0.010
# 回合：2010/5000，奖励：500.00，Epislon：0.010
# 回合：2020/5000，奖励：458.00，Epislon：0.010
# 回合：2030/5000，奖励：207.00，Epislon：0.010
# 回合：2040/5000，奖励：23.00，Epislon：0.010
# 回合：2050/5000，奖励：500.00，Epislon：0.010
# 回合：2060/5000，奖励：481.00，Epislon：0.010
# 回合：2070/5000，奖励：500.00，Epislon：0.010
# 回合：2080/5000，奖励：500.00，Epislon：0.010
# 回合：2090/5000，奖励：500.00，Epislon：0.010
# 回合：2100/5000，奖励：500.00，Epislon：0.010
# 回合：2110/5000，奖励：500.00，Epislon：0.010
# 回合：2120/5000，奖励：500.00，Epislon：0.010
# 回合：2130/5000，奖励：500.00，Epislon：0.010
# 回合：2140/5000，奖励：500.00，Epislon：0.010
# 回合：2150/5000，奖励：500.00，Epislon：0.010
# 回合：2160/5000，奖励：293.00，Epislon：0.010
# 回合：2170/5000，奖励：500.00，Epislon：0.010
# 回合：2180/5000，奖励：393.00，Epislon：0.010
# 回合：2190/5000，奖励：500.00，Epislon：0.010
# 回合：2200/5000，奖励：500.00，Epislon：0.010
# 回合：2210/5000，奖励：500.00，Epislon：0.010
# 回合：2220/5000，奖励：101.00，Epislon：0.010
# 回合：2230/5000，奖励：340.00，Epislon：0.010
# 回合：2240/5000，奖励：316.00，Epislon：0.010
# 回合：2250/5000，奖励：136.00，Epislon：0.010
# 回合：2260/5000，奖励：148.00，Epislon：0.010
# 回合：2270/5000，奖励：500.00，Epislon：0.010
# 回合：2280/5000，奖励：146.00，Epislon：0.010
# 回合：2290/5000，奖励：36.00，Epislon：0.010
# 回合：2300/5000，奖励：147.00，Epislon：0.010
# 回合：2310/5000，奖励：500.00，Epislon：0.010
# 回合：2320/5000，奖励：107.00，Epislon：0.010
# 回合：2330/5000，奖励：54.00，Epislon：0.010
# 回合：2340/5000，奖励：51.00，Epislon：0.010
# 回合：2350/5000，奖励：222.00，Epislon：0.010
# 回合：2360/5000，奖励：394.00，Epislon：0.010
# 回合：2370/5000，奖励：310.00，Epislon：0.010
# 回合：2380/5000，奖励：437.00，Epislon：0.010
# 回合：2390/5000，奖励：210.00，Epislon：0.010
# 回合：2400/5000，奖励：362.00，Epislon：0.010
# 回合：2410/5000，奖励：152.00，Epislon：0.010
# 回合：2420/5000，奖励：157.00，Epislon：0.010
# 回合：2430/5000，奖励：170.00，Epislon：0.010
# 回合：2440/5000，奖励：169.00，Epislon：0.010
# 回合：2450/5000，奖励：156.00，Epislon：0.010
# 回合：2460/5000，奖励：144.00，Epislon：0.010
# 回合：2470/5000，奖励：144.00，Epislon：0.010
# 回合：2480/5000，奖励：500.00，Epislon：0.010
# 回合：2490/5000，奖励：148.00，Epislon：0.010
# 回合：2500/5000，奖励：470.00，Epislon：0.010
# 回合：2510/5000，奖励：500.00，Epislon：0.010
# 回合：2520/5000，奖励：161.00，Epislon：0.010
# 回合：2530/5000，奖励：239.00，Epislon：0.010
# 回合：2540/5000，奖励：206.00，Epislon：0.010
# 回合：2550/5000，奖励：328.00，Epislon：0.010
# 回合：2560/5000，奖励：426.00，Epislon：0.010
# 回合：2570/5000，奖励：281.00，Epislon：0.010
# 回合：2580/5000，奖励：467.00，Epislon：0.010
# 回合：2590/5000，奖励：139.00，Epislon：0.010
# 回合：2600/5000，奖励：186.00，Epislon：0.010
# 回合：2610/5000，奖励：287.00，Epislon：0.010
# 回合：2620/5000，奖励：217.00，Epislon：0.010
# 回合：2630/5000，奖励：361.00，Epislon：0.010
# 回合：2640/5000，奖励：166.00，Epislon：0.010
# 回合：2650/5000，奖励：293.00，Epislon：0.010
# 回合：2660/5000，奖励：500.00，Epislon：0.010
# 回合：2670/5000，奖励：152.00，Epislon：0.010
# 回合：2680/5000，奖励：153.00，Epislon：0.010
# 回合：2690/5000，奖励：174.00，Epislon：0.010
# 回合：2700/5000，奖励：14.00，Epislon：0.010
# 回合：2710/5000，奖励：164.00，Epislon：0.010
# 回合：2720/5000，奖励：160.00，Epislon：0.010
# 回合：2730/5000，奖励：167.00，Epislon：0.010
# 回合：2740/5000，奖励：190.00，Epislon：0.010
# 回合：2750/5000，奖励：500.00，Epislon：0.010
# 回合：2760/5000，奖励：500.00，Epislon：0.010
# 回合：2770/5000，奖励：196.00，Epislon：0.010
# 回合：2780/5000，奖励：176.00，Epislon：0.010
# 回合：2790/5000，奖励：187.00，Epislon：0.010
# 回合：2800/5000，奖励：181.00，Epislon：0.010
# 回合：2810/5000，奖励：173.00，Epislon：0.010
# 回合：2820/5000，奖励：226.00，Epislon：0.010
# 回合：2830/5000，奖励：397.00，Epislon：0.010
# 回合：2840/5000，奖励：167.00，Epislon：0.010
# 回合：2850/5000，奖励：184.00，Epislon：0.010
# 回合：2860/5000，奖励：349.00，Epislon：0.010
# 回合：2870/5000，奖励：169.00，Epislon：0.010
# 回合：2880/5000，奖励：201.00，Epislon：0.010
# 回合：2890/5000，奖励：169.00，Epislon：0.010
# 回合：2900/5000，奖励：199.00，Epislon：0.010
# 回合：2910/5000，奖励：184.00，Epislon：0.010
# 回合：2920/5000，奖励：167.00，Epislon：0.010
# 回合：2930/5000，奖励：178.00，Epislon：0.010
# 回合：2940/5000，奖励：194.00，Epislon：0.010
# 回合：2950/5000，奖励：153.00，Epislon：0.010
# 回合：2960/5000，奖励：265.00，Epislon：0.010
# 回合：2970/5000，奖励：83.00，Epislon：0.010
# 回合：2980/5000，奖励：213.00，Epislon：0.010
# 回合：2990/5000，奖励：147.00，Epislon：0.010
# 回合：3000/5000，奖励：198.00，Epislon：0.010
# 回合：3010/5000，奖励：163.00，Epislon：0.010
# 回合：3020/5000，奖励：196.00，Epislon：0.010
# 回合：3030/5000，奖励：203.00，Epislon：0.010
# 回合：3040/5000，奖励：55.00，Epislon：0.010
# 回合：3050/5000，奖励：70.00，Epislon：0.010
# 回合：3060/5000，奖励：56.00，Epislon：0.010
# 回合：3070/5000，奖励：204.00，Epislon：0.010
# 回合：3080/5000，奖励：500.00，Epislon：0.010
# 回合：3090/5000，奖励：182.00，Epislon：0.010
# 回合：3100/5000，奖励：169.00，Epislon：0.010
# 回合：3110/5000，奖励：154.00，Epislon：0.010
# 回合：3120/5000，奖励：140.00，Epislon：0.010
# 回合：3130/5000，奖励：208.00，Epislon：0.010
# 回合：3140/5000，奖励：203.00，Epislon：0.010
# 回合：3150/5000，奖励：165.00，Epislon：0.010
# 回合：3160/5000，奖励：177.00，Epislon：0.010
# 回合：3170/5000，奖励：500.00，Epislon：0.010
# 回合：3180/5000，奖励：487.00，Epislon：0.010
# 回合：3190/5000，奖励：203.00，Epislon：0.010
# 回合：3200/5000，奖励：214.00，Epislon：0.010
# 回合：3210/5000，奖励：447.00，Epislon：0.010
# 回合：3220/5000，奖励：500.00，Epislon：0.010
# 回合：3230/5000，奖励：500.00，Epislon：0.010
# 回合：3240/5000，奖励：160.00，Epislon：0.010
# 回合：3250/5000，奖励：197.00，Epislon：0.010
# 回合：3260/5000，奖励：325.00，Epislon：0.010
# 回合：3270/5000，奖励：500.00，Epislon：0.010
# 回合：3280/5000，奖励：195.00，Epislon：0.010
# 回合：3290/5000，奖励：186.00，Epislon：0.010
# 回合：3300/5000，奖励：246.00，Epislon：0.010
# 回合：3310/5000，奖励：229.00，Epislon：0.010
# 回合：3320/5000，奖励：500.00，Epislon：0.010
# 回合：3330/5000，奖励：262.00，Epislon：0.010
# 回合：3340/5000，奖励：480.00，Epislon：0.010
# 回合：3350/5000，奖励：429.00，Epislon：0.010
# 回合：3360/5000，奖励：301.00，Epislon：0.010
# 回合：3370/5000，奖励：187.00，Epislon：0.010
# 回合：3380/5000，奖励：361.00，Epislon：0.010
# 回合：3390/5000，奖励：274.00，Epislon：0.010
# 回合：3400/5000，奖励：139.00，Epislon：0.010
# 回合：3410/5000，奖励：74.00，Epislon：0.010
# 回合：3420/5000，奖励：371.00，Epislon：0.010
# 回合：3430/5000，奖励：166.00，Epislon：0.010
# 回合：3440/5000，奖励：464.00，Epislon：0.010
# 回合：3450/5000，奖励：164.00，Epislon：0.010
# 回合：3460/5000，奖励：500.00，Epislon：0.010
# 回合：3470/5000，奖励：164.00，Epislon：0.010
# 回合：3480/5000，奖励：152.00，Epislon：0.010
# 回合：3490/5000，奖励：174.00，Epislon：0.010
# 回合：3500/5000，奖励：500.00，Epislon：0.010
# 回合：3510/5000，奖励：226.00，Epislon：0.010
# 回合：3520/5000，奖励：211.00，Epislon：0.010
# 回合：3530/5000，奖励：500.00，Epislon：0.010
# 回合：3540/5000，奖励：209.00，Epislon：0.010
# 回合：3550/5000，奖励：195.00，Epislon：0.010
# 回合：3560/5000，奖励：500.00，Epislon：0.010
# 回合：3570/5000，奖励：243.00，Epislon：0.010
# 回合：3580/5000，奖励：212.00，Epislon：0.010
# 回合：3590/5000，奖励：500.00，Epislon：0.010
# 回合：3600/5000，奖励：230.00，Epislon：0.010
# 回合：3610/5000，奖励：227.00，Epislon：0.010
# 回合：3620/5000，奖励：175.00，Epislon：0.010
# 回合：3630/5000，奖励：225.00，Epislon：0.010
# 回合：3640/5000，奖励：500.00，Epislon：0.010
# 回合：3650/5000，奖励：500.00，Epislon：0.010
# 回合：3660/5000，奖励：284.00，Epislon：0.010
# 回合：3670/5000，奖励：163.00，Epislon：0.010
# 回合：3680/5000，奖励：224.00，Epislon：0.010
# 回合：3690/5000，奖励：500.00，Epislon：0.010
# 回合：3700/5000，奖励：342.00，Epislon：0.010
# 回合：3710/5000，奖励：500.00，Epislon：0.010
# 回合：3720/5000，奖励：148.00，Epislon：0.010
# 回合：3730/5000，奖励：177.00，Epislon：0.010
# 回合：3740/5000，奖励：247.00，Epislon：0.010
# 回合：3750/5000，奖励：256.00，Epislon：0.010
# 回合：3760/5000，奖励：169.00，Epislon：0.010
# 回合：3770/5000，奖励：161.00，Epislon：0.010
# 回合：3780/5000，奖励：231.00，Epislon：0.010
# 回合：3790/5000，奖励：276.00，Epislon：0.010
# 回合：3800/5000，奖励：228.00，Epislon：0.010
# 回合：3810/5000，奖励：229.00，Epislon：0.010
# 回合：3820/5000，奖励：153.00，Epislon：0.010
# 回合：3830/5000，奖励：258.00，Epislon：0.010
# 回合：3840/5000，奖励：154.00，Epislon：0.010
# 回合：3850/5000，奖励：153.00，Epislon：0.010
# 回合：3860/5000，奖励：199.00，Epislon：0.010
# 回合：3870/5000，奖励：262.00，Epislon：0.010
# 回合：3880/5000，奖励：167.00，Epislon：0.010
# 回合：3890/5000，奖励：210.00，Epislon：0.010
# 回合：3900/5000，奖励：231.00，Epislon：0.010
# 回合：3910/5000，奖励：500.00，Epislon：0.010
# 回合：3920/5000，奖励：236.00，Epislon：0.010
# 回合：3930/5000，奖励：166.00，Epislon：0.010
# 回合：3940/5000，奖励：209.00，Epislon：0.010
# 回合：3950/5000，奖励：500.00，Epislon：0.010
# 回合：3960/5000，奖励：176.00，Epislon：0.010
# 回合：3970/5000，奖励：317.00，Epislon：0.010
# 回合：3980/5000，奖励：177.00，Epislon：0.010
# 回合：3990/5000，奖励：168.00，Epislon：0.010
# 回合：4000/5000，奖励：188.00，Epislon：0.010
# 回合：4010/5000，奖励：180.00，Epislon：0.010
# 回合：4020/5000，奖励：179.00，Epislon：0.010
# 回合：4030/5000，奖励：175.00，Epislon：0.010
# 回合：4040/5000，奖励：184.00，Epislon：0.010
# 回合：4050/5000，奖励：162.00，Epislon：0.010
# 回合：4060/5000，奖励：221.00，Epislon：0.010
# 回合：4070/5000，奖励：500.00，Epislon：0.010
# 回合：4080/5000，奖励：172.00，Epislon：0.010
# 回合：4090/5000，奖励：178.00，Epislon：0.010
# 回合：4100/5000，奖励：428.00，Epislon：0.010
# 回合：4110/5000，奖励：177.00，Epislon：0.010
# 回合：4120/5000，奖励：204.00，Epislon：0.010
# 回合：4130/5000，奖励：500.00，Epislon：0.010
# 回合：4140/5000，奖励：185.00，Epislon：0.010
# 回合：4150/5000，奖励：500.00，Epislon：0.010
# 回合：4160/5000，奖励：169.00，Epislon：0.010
# 回合：4170/5000，奖励：176.00，Epislon：0.010
# 回合：4180/5000，奖励：166.00，Epislon：0.010
# 回合：4190/5000，奖励：289.00，Epislon：0.010
# 回合：4200/5000，奖励：500.00，Epislon：0.010
# 回合：4210/5000，奖励：500.00，Epislon：0.010
# 回合：4220/5000，奖励：178.00，Epislon：0.010
# 回合：4230/5000，奖励：170.00，Epislon：0.010
# 回合：4240/5000，奖励：500.00，Epislon：0.010
# 回合：4250/5000，奖励：210.00，Epislon：0.010
# 回合：4260/5000，奖励：168.00，Epislon：0.010
# 回合：4270/5000，奖励：155.00，Epislon：0.010
# 回合：4280/5000，奖励：202.00，Epislon：0.010
# 回合：4290/5000，奖励：177.00，Epislon：0.010
# 回合：4300/5000，奖励：167.00，Epislon：0.010
# 回合：4310/5000，奖励：189.00，Epislon：0.010
# 回合：4320/5000，奖励：500.00，Epislon：0.010
# 回合：4330/5000，奖励：175.00，Epislon：0.010
# 回合：4340/5000，奖励：183.00，Epislon：0.010
# 回合：4350/5000，奖励：165.00，Epislon：0.010
# 回合：4360/5000，奖励：233.00，Epislon：0.010
# 回合：4370/5000，奖励：178.00，Epislon：0.010
# 回合：4380/5000，奖励：160.00，Epislon：0.010
# 回合：4390/5000，奖励：500.00，Epislon：0.010
# 回合：4400/5000，奖励：148.00，Epislon：0.010
# 回合：4410/5000，奖励：162.00，Epislon：0.010
# 回合：4420/5000，奖励：155.00，Epislon：0.010
# 回合：4430/5000，奖励：164.00，Epislon：0.010
# 回合：4440/5000，奖励：169.00，Epislon：0.010
# 回合：4450/5000，奖励：164.00，Epislon：0.010
# 回合：4460/5000，奖励：169.00，Epislon：0.010
# 回合：4470/5000，奖励：176.00，Epislon：0.010
# 回合：4480/5000，奖励：161.00，Epislon：0.010
# 回合：4490/5000，奖励：183.00，Epislon：0.010
# 回合：4500/5000，奖励：178.00，Epislon：0.010
# 回合：4510/5000，奖励：185.00，Epislon：0.010
# 回合：4520/5000，奖励：190.00，Epislon：0.010
# 回合：4530/5000，奖励：167.00，Epislon：0.010
# 回合：4540/5000，奖励：154.00，Epislon：0.010
# 回合：4550/5000，奖励：169.00，Epislon：0.010
# 回合：4560/5000，奖励：158.00，Epislon：0.010
# 回合：4570/5000，奖励：162.00，Epislon：0.010
# 回合：4580/5000，奖励：191.00，Epislon：0.010
# 回合：4590/5000，奖励：159.00，Epislon：0.010
# 回合：4600/5000，奖励：207.00，Epislon：0.010
# 回合：4610/5000，奖励：199.00，Epislon：0.010
# 回合：4620/5000，奖励：170.00，Epislon：0.010
# 回合：4630/5000，奖励：192.00，Epislon：0.010
# 回合：4640/5000，奖励：185.00，Epislon：0.010
# 回合：4650/5000，奖励：163.00，Epislon：0.010
# 回合：4660/5000，奖励：186.00，Epislon：0.010
# 回合：4670/5000，奖励：183.00，Epislon：0.010
# 回合：4680/5000，奖励：205.00，Epislon：0.010
# 回合：4690/5000，奖励：158.00，Epislon：0.010
# 回合：4700/5000，奖励：167.00，Epislon：0.010
# 回合：4710/5000，奖励：189.00，Epislon：0.010
# 回合：4720/5000，奖励：171.00，Epislon：0.010
# 回合：4730/5000，奖励：170.00，Epislon：0.010
# 回合：4740/5000，奖励：180.00，Epislon：0.010
# 回合：4750/5000，奖励：500.00，Epislon：0.010
# 回合：4760/5000，奖励：200.00，Epislon：0.010
# 回合：4770/5000，奖励：176.00，Epislon：0.010
# 回合：4780/5000，奖励：161.00，Epislon：0.010
# 回合：4790/5000，奖励：174.00，Epislon：0.010
# 回合：4800/5000，奖励：161.00，Epislon：0.010
# 回合：4810/5000，奖励：176.00，Epislon：0.010
# 回合：4820/5000，奖励：168.00，Epislon：0.010
# 回合：4830/5000，奖励：116.00，Epislon：0.010
# 回合：4840/5000，奖励：180.00，Epislon：0.010
# 回合：4850/5000，奖励：131.00，Epislon：0.010
# 回合：4860/5000，奖励：144.00，Epislon：0.010
# 回合：4870/5000，奖励：156.00，Epislon：0.010
# 回合：4880/5000，奖励：148.00，Epislon：0.010
# 回合：4890/5000，奖励：166.00，Epislon：0.010
# 回合：4900/5000，奖励：188.00，Epislon：0.010
# 回合：4910/5000，奖励：152.00，Epislon：0.010
# 回合：4920/5000，奖励：500.00，Epislon：0.010
# 回合：4930/5000，奖励：166.00，Epislon：0.010
# 回合：4940/5000，奖励：150.00，Epislon：0.010
# 回合：4950/5000，奖励：164.00，Epislon：0.010
# 回合：4960/5000，奖励：158.00，Epislon：0.010
# 回合：4970/5000，奖励：196.00，Epislon：0.010
# 回合：4980/5000，奖励：10.00，Epislon：0.010
# 回合：4990/5000，奖励：12.00，Epislon：0.010
# 回合：5000/5000，奖励：10.00，Epislon：0.010
# 完成训练！
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# 开始测试！
# 回合：1/20，奖励：9.00
# 回合：2/20，奖励：8.00
# 回合：3/20，奖励：9.00
# 回合：4/20，奖励：9.00
# 回合：5/20，奖励：10.00
# 回合：6/20，奖励：10.00
# 回合：7/20，奖励：8.00
# 回合：8/20，奖励：10.00
# 回合：9/20，奖励：10.00
# 回合：10/20，奖励：8.00
# 回合：11/20，奖励：8.00
# 回合：12/20，奖励：10.00
# 回合：13/20，奖励：10.00
# 回合：14/20，奖励：10.00
# 回合：15/20，奖励：9.00
# 回合：16/20，奖励：10.00
# 回合：17/20，奖励：10.00
# 回合：18/20，奖励：10.00
# 回合：19/20，奖励：8.00
# 回合：20/20，奖励：9.00
# 完成测试

# %%
state = env.reset()
for _ in range(500):
    env.render()
    action = agent.predict_action(state)
    next_state, reward, done, _ = env.step(action)
    state = next_state
env.close()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /var/folders/rc/4jr_8mlj2ng1hg4rbf4lzk1w0000gn/T/ipykernel_5612/2015173130.py:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   weight = self.weight_mu + self.weight_sigma.mul(torch.tensor(self.weight_epsilon))
# /var/folders/rc/4jr_8mlj2ng1hg4rbf4lzk1w0000gn/T/ipykernel_5612/2015173130.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   bias   = self.bias_mu   + self.bias_sigma.mul(torch.tensor(self.bias_epsilon))
# /opt/anaconda3/lib/python3.12/site-packages/gym/envs/classic_control/cartpole.py:179: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
