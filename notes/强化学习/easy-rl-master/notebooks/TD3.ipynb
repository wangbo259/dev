# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque

# %% [markdown]
# ## 1.定义算法
# ### 1.1 建立Actor和Critic网络

# %%
class Actor(nn.Module):
	
	def __init__(self, n_states, n_actions, hidden_dim = 256):	
		""" 初始化Actor网络，为全连接网络
		"""
		super(Actor, self).__init__()
		self.l1 = nn.Linear(n_states, hidden_dim)
		self.l2 = nn.Linear(hidden_dim, hidden_dim)
		self.l3 = nn.Linear(hidden_dim, n_actions)
	
	def forward(self, state):
		
		x = F.relu(self.l1(state))
		x = F.relu(self.l2(x))
		x = torch.tanh(self.l3(x))
		return x

class Critic(nn.Module):
	def __init__(self, n_states, n_actions, hidden_dim = 256):
		""" 初始化Critic网络，为全连接网络
		"""
		super(Critic,self).__init__()
		self.l1 = nn.Linear(n_states + n_actions, 256)
		self.l2 = nn.Linear(hidden_dim, hidden_dim)
		self.l3 = nn.Linear(hidden_dim, 1)

	def forward(self, state, action):
		sa = torch.cat([state, action], 1)
		q = F.relu(self.l1(sa))
		q = F.relu(self.l2(q))
		q = self.l3(q)
		return q

# %% [markdown]
# ### 1.2 定义经验回放

# %%
class ReplayBufferQue:
    def __init__(self, capacity: int) -> None:
        self.capacity = capacity
        self.buffer = deque(maxlen=self.capacity)
    def push(self,transitions):
        ''' 存储transition到经验回放中
        '''
        self.buffer.append(transitions)
    def sample(self, batch_size: int, sequential: bool = False):
        if batch_size > len(self.buffer): # 如果批量大小大于经验回放的容量，则取经验回放的容量
            batch_size = len(self.buffer)
        if sequential: # 顺序采样
            rand = random.randint(0, len(self.buffer) - batch_size)
            batch = [self.buffer[i] for i in range(rand, rand + batch_size)]
            return zip(*batch)
        else: # 随机采样
            batch = random.sample(self.buffer, batch_size)
            return zip(*batch)
    def clear(self):
        ''' 清空经验回放
        '''
        self.buffer.clear()
    def __len__(self):
         ''' 返回当前存储的量
        '''
        
         return len(self.buffer)

# %% [markdown]
# ### 1.3 TD3算法

# %%
class TD3(object):
	def __init__(self,cfg):
		self.gamma = cfg.gamma # 奖励的折扣因子
		self.actor_lr = cfg.actor_lr # actor学习率
		self.critic_lr = cfg.critic_lr # critic学习率
		self.policy_noise = cfg.policy_noise
		self.noise_clip = cfg.noise_clip
		self.expl_noise = cfg.expl_noise
		self.policy_freq = cfg.policy_freq
		self.batch_size =  cfg.batch_size 
		self.tau = cfg.tau
		self.sample_count = 0
		self.policy_freq = cfg.policy_freq
		self.explore_steps = cfg.explore_steps
		self.device = torch.device(cfg.device)
		self.n_actions = cfg.n_actions
		self.action_space = cfg.action_space
		self.action_scale = torch.tensor((self.action_space.high - self.action_space.low)/2, device=self.device, dtype=torch.float32).unsqueeze(dim=0)
		self.action_bias = torch.tensor((self.action_space.high + self.action_space.low)/2, device=self.device, dtype=torch.float32).unsqueeze(dim=0)
		self.actor = Actor(cfg.n_states, cfg.n_actions, hidden_dim = cfg.actor_hidden_dim).to(self.device)
		self.actor_target = Actor(cfg.n_states, cfg.n_actions, hidden_dim = cfg.actor_hidden_dim).to(self.device)
		self.actor_target.load_state_dict(self.actor.state_dict()) # 复制参数到目标网络

		self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr = self.actor_lr)

		self.critic_1 = Critic(cfg.n_states, cfg.n_actions, hidden_dim = cfg.critic_hidden_dim).to(self.device)
		self.critic_2 = Critic(cfg.n_states, cfg.n_actions, hidden_dim = cfg.critic_hidden_dim).to(self.device)
		self.critic_1_target = Critic(cfg.n_states, cfg.n_actions, hidden_dim = cfg.critic_hidden_dim).to(self.device)
		self.critic_2_target = Critic(cfg.n_states, cfg.n_actions, hidden_dim = cfg.critic_hidden_dim).to(self.device)
		self.critic_1_target.load_state_dict(self.critic_1.state_dict()) # 复制参数到目标网络
		self.critic_2_target.load_state_dict(self.critic_2.state_dict()) # 复制参数到目标网络
		
		self.critic_1_optimizer = torch.optim.Adam(self.critic_1.parameters(), lr = self.critic_lr)
		self.critic_2_optimizer = torch.optim.Adam(self.critic_2.parameters(), lr = self.critic_lr)
		self.memory = ReplayBufferQue(cfg.buffer_size)
		# self.memory = ReplayBuffer(n_states, n_actions)

	def sample_action(self, state):
		''' 采样动作
		'''

		self.sample_count += 1
		if self.sample_count < self.explore_steps:
			return self.action_space.sample()
		else:
			state = torch.tensor(state, device=self.device, dtype=torch.float32).unsqueeze(dim=0)
			action = self.actor(state)
			action = self.action_scale * action + self.action_bias
			action = action.detach().cpu().numpy()[0]
			action_noise = np.random.normal(0, self.action_scale.cpu().numpy()[0] * self.expl_noise, size=self.n_actions)
			action = (action + action_noise).clip(self.action_space.low, self.action_space.high)
			return action

	@torch.no_grad()
	def predict_action(self, state):
		''' 预测动作
		'''
		state = torch.tensor(state, device=self.device, dtype=torch.float32).unsqueeze(dim=0)
		action = self.actor(state)
		action = self.action_scale * action + self.action_bias # 对actor计算的动作分布放缩
		return action.detach().cpu().numpy()[0]

	def update(self):
		# if len(self.memory) < self.batch_size:
		# 	return
		if len(self.memory) < self.explore_steps: # 当经验回放中不满足一个批量时，不更新策略
			return
		state, action, reward, next_state, done = self.memory.sample(self.batch_size) # 从经验回放中随机采样一个批量的转移(transition)
         # 将数据转换为tensor
		state = torch.tensor(np.array(state), device=self.device, dtype=torch.float32)
		action = torch.tensor(np.array(action), device=self.device, dtype=torch.float32)
		next_state = torch.tensor(np.array(next_state), device=self.device, dtype=torch.float32)
		reward = torch.tensor(reward, device=self.device, dtype=torch.float32).unsqueeze(1)
		done = torch.tensor(done, device=self.device, dtype=torch.float32).unsqueeze(1)
		# update critic
		noise = (torch.randn_like(action) * self.policy_noise).clamp(-self.noise_clip, self.noise_clip) # 构造加入目标动作的噪声
        # 计算加入了噪声的目标动作
		next_action = (self.actor_target(next_state) + noise).clamp(-self.action_scale+self.action_bias, self.action_scale+self.action_bias)
        # 计算两个critic网络对t+1时刻的状态动作对的评分，并选取更小值来计算目标q值
		target_q1, target_q2 = self.critic_1_target(next_state, next_action).detach(), self.critic_2_target(next_state, next_action).detach()
		target_q = torch.min(target_q1, target_q2)
		target_q = reward + self.gamma * target_q * (1 - done)
        # 计算两个critic网络对t时刻的状态动作对的评分
		current_q1, current_q2 = self.critic_1(state, action), self.critic_2(state, action)
        # 计算均方根损失
		critic_1_loss = F.mse_loss(current_q1, target_q)
		critic_2_loss = F.mse_loss(current_q2, target_q)
		self.critic_1_optimizer.zero_grad()
		critic_1_loss.backward()
		self.critic_1_optimizer.step()
		self.critic_2_optimizer.zero_grad()
		critic_2_loss.backward()
		self.critic_2_optimizer.step()
		if self.sample_count % self.policy_freq == 0:
            # 延迟策略更新，actor的更新频率低于critic
			actor_loss = -self.critic_1(state, self.actor(state)).mean()
			self.actor_optimizer.zero_grad()
			actor_loss.backward()
			self.actor_optimizer.step()
            #目标网络软更新
			for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
			for param, target_param in zip(self.critic_1.parameters(), self.critic_1_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
			for param, target_param in zip(self.critic_2.parameters(), self.critic_2_target.parameters()):
				target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

# %% [markdown]
# ## 2.模型训练与测试

# %%
def train(cfg, env, agent):
    print("开始训练！")
    rewards = [] # 记录所有回合的奖励
    for i_ep in range(cfg.train_eps):
        state = env.reset() # 重置环境，返回初始状态
        ep_reward = 0 # 记录一回合内的奖励
        for i_step in range(cfg.max_steps):
            action = agent.sample_action(state)  # 抽样动作
            next_state, reward, terminated, info = env.step(action)  # 更新环境，返回transitions
            agent.memory.push((state, action, reward,
                            next_state, terminated))  # 保存transition
            agent.update()   # 更新智能体
            state = next_state  # 更新下一个状态
            ep_reward += reward  # 累加奖励
            if terminated:
                break
        if (i_ep+1)%10 == 0:
            print(f"回合：{i_ep+1}/{cfg.train_eps}，奖励：{ep_reward:.2f}")
        rewards.append(ep_reward)
    print("完成训练！")
    return {'rewards':rewards}
def test(cfg, env, agent):
    print("开始测试！")
    rewards = [] # 记录所有回合的奖励
    for i_ep in range(cfg.train_eps):
        state = env.reset() # 重置环境，返回初始状态
        ep_reward = 0 # 记录一回合内的奖励
        for i_step in range(cfg.max_steps):
            action = agent.sample_action(state)  # 抽样动作
            next_state, reward, terminated, info = env.step(action)  # 更新环境，返回transitions
            state = next_state  # 更新下一个状态
            ep_reward += reward  # 累加奖励
            if terminated:
                break
        rewards.append(ep_reward)
        print(f"回合：{i_ep+1}/{cfg.test_eps}，奖励：{ep_reward:.2f}")
    print("完成测试！")
    return {'rewards':rewards}

# %% [markdown]
# ## 3.定义环境

# %%
import gym
import os
import random
def all_seed(env,seed = 1):
    ''' 万能的seed函数
    '''
    env.seed(seed) # env config
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed) # config for CPU
    torch.cuda.manual_seed(seed) # config for GPU
    os.environ['PYTHONHASHSEED'] = str(seed) # config for python scripts
    # config for cudnn
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.enabled = False
def env_agent_config(cfg):
    env = gym.make(cfg.env_name) # 创建环境
    all_seed(env,seed=cfg.seed)
    n_states = env.observation_space.shape[0]
    n_actions = env.action_space.shape[0]
    print(f"状态空间维度：{n_states}，动作空间维度：{n_actions}")
    # 更新n_states和n_actions到cfg参数中
    setattr(cfg, 'n_states', n_states)
    setattr(cfg, 'n_actions', n_actions) 
    setattr(cfg, 'action_space', env.action_space) 
    models = {"actor":Actor(n_states,n_actions,hidden_dim=cfg.actor_hidden_dim),"critic":Critic(n_states,n_actions,hidden_dim=cfg.critic_hidden_dim)}
    memory = ReplayBufferQue(cfg.buffer_size) # 创建经验池
    agent = TD3(cfg)
    return env,agent
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 4.设置参数

# %%
import argparse
import matplotlib.pyplot as plt
import seaborn as sns
class Config:
    def __init__(self):
        self.seed = 123
        self.explore_steps = 5
        self.algo_name = 'TD3' # 算法名称
        self.env_name = 'Pendulum-v1' # 环境名称
        self.device = "cpu" # 使用设备
        self.train_eps = 1000 # 训练迭代次数
        self.test_eps = 50 # 测试迭代次数
        self.eval_eps = 10 # 评估迭代次数
        self.eval_per_episode = 5 # 每隔几代评估
        self.max_steps = 200 # 每次迭代最大时间步
        self.policy_freq = 2  # 策略网络更新频率
        self.actor_lr = 1e-3 
        self.critic_lr = 1e-3 
        self.actor_hidden_dim = 256 # actor网络隐藏层维度
        self.critic_hidden_dim = 256 # critic网络隐藏层维度
        self.gamma = 0.99 
        self.tau = 0.005 # 目标网络软更新系数
        self.policy_noise = 0.2 # 加入策略网络的噪声
        self.expl_noise = 0.1 # 高斯噪声标准差
        self.noise_clip = 0.5 # 加入策略网络噪声范围
        self.batch_size = 100 # 训练批次大小
        self.buffer_size = 1000000 # 经验回放池大小
def smooth(data, weight=0.9):  
    '''用于平滑曲线，类似于Tensorboard中的smooth曲线
    '''
    last = data[0] 
    smoothed = []
    for point in data:
        smoothed_val = last * weight + (1 - weight) * point  # 计算平滑值
        smoothed.append(smoothed_val)                    
        last = smoothed_val                                
    return smoothed

def plot_rewards(rewards,title="learning curve"):
    sns.set()
    plt.figure()  # 创建一个图形实例，方便同时多画几个图
    plt.title(f"{title}")
    plt.xlim(0, len(rewards))  # 设置x轴的范围
    plt.xlabel('epsiodes')
    plt.plot(rewards, label='rewards')
    plt.plot(smooth(rewards), label='smoothed')
    plt.legend()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 5.开始训练

# %%
# 获取参数
cfg = Config() 
# 训练
env, agent = env_agent_config(cfg)
res_dic = train(cfg, env, agent)
 
plot_rewards(res_dic['rewards'], title=f"training curve on {cfg.device} of {cfg.algo_name} for {cfg.env_name}")  
# 测试
res_dic = test(cfg, env, agent)
plot_rewards(res_dic['rewards'], title=f"testing curve on {cfg.device} of {cfg.algo_name} for {cfg.env_name}")  # 画出结果
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/lib/python3.12/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /opt/anaconda3/lib/python3.12/site-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(
# /opt/anaconda3/lib/python3.12/site-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 状态空间维度：3，动作空间维度：1
# 开始训练！
# /opt/anaconda3/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# 回合：10/1000，奖励：-1526.25
# 回合：20/1000，奖励：-1165.23
# 回合：30/1000，奖励：-877.16
# 回合：40/1000，奖励：-127.72
# 回合：50/1000，奖励：-114.26
# 回合：60/1000，奖励：-119.04
# 回合：70/1000，奖励：-445.09
# 回合：80/1000，奖励：-224.18
# 回合：90/1000，奖励：-124.77
# 回合：100/1000，奖励：-239.87
# 回合：110/1000，奖励：-2.37
# 回合：120/1000，奖励：-115.61
# 回合：130/1000，奖励：-234.39
# 回合：140/1000，奖励：-118.19
# 回合：150/1000，奖励：-123.47
# 回合：160/1000，奖励：-120.91
# 回合：170/1000，奖励：-114.63
# 回合：180/1000，奖励：-1513.07
# 回合：190/1000，奖励：-236.59
# 回合：200/1000，奖励：-237.62
# 回合：210/1000，奖励：-130.04
# 回合：220/1000，奖励：-116.98
# 回合：230/1000，奖励：-121.18
# 回合：240/1000，奖励：-1.43
# 回合：250/1000，奖励：-349.11
# 回合：260/1000，奖励：-246.09
# 回合：270/1000，奖励：-122.90
# 回合：280/1000，奖励：-240.03
# 回合：290/1000，奖励：-1.66
# 回合：300/1000，奖励：-116.42
# 回合：310/1000，奖励：-366.17
# 回合：320/1000，奖励：-244.19
# 回合：330/1000，奖励：-123.65
# 回合：340/1000，奖励：-116.21
# 回合：350/1000，奖励：-241.39
# 回合：360/1000，奖励：-334.25
# 回合：370/1000，奖励：-119.46
# 回合：380/1000，奖励：-119.45
# 回合：390/1000，奖励：-249.49
# 回合：400/1000，奖励：-232.35
# 回合：410/1000，奖励：-321.67
# 回合：420/1000，奖励：-1.61
# 回合：430/1000，奖励：-115.46
# 回合：440/1000，奖励：-2.92
# 回合：450/1000，奖励：-126.47
# 回合：460/1000，奖励：-119.95
# 回合：470/1000，奖励：-122.57
# 回合：480/1000，奖励：-240.65
# 回合：490/1000，奖励：-119.99
# 回合：500/1000，奖励：-120.22
# 回合：510/1000，奖励：-340.55
# 回合：520/1000，奖励：-125.01
# 回合：530/1000，奖励：-234.50
# 回合：540/1000，奖励：-0.86
# 回合：550/1000，奖励：-119.15
# 回合：560/1000，奖励：-118.13
# 回合：570/1000，奖励：-225.08
# 回合：580/1000，奖励：-233.10
# 回合：590/1000，奖励：-230.89
# 回合：600/1000，奖励：-1.58
# 回合：610/1000，奖励：-346.10
# 回合：620/1000，奖励：-125.39
# 回合：630/1000，奖励：-116.46
# 回合：640/1000，奖励：-237.78
# 回合：650/1000，奖励：-124.48
# 回合：660/1000，奖励：-124.05
# 回合：670/1000，奖励：-374.28
# 回合：680/1000，奖励：-283.32
# 回合：690/1000，奖励：-233.39
# 回合：700/1000，奖励：-243.12
# 回合：710/1000，奖励：-118.79
# 回合：720/1000，奖励：-254.84
# 回合：730/1000，奖励：-121.32
# 回合：740/1000，奖励：-126.68
# 回合：750/1000，奖励：-116.82
# 回合：760/1000，奖励：-122.84
# 回合：770/1000，奖励：-119.44
# 回合：780/1000，奖励：-238.60
# 回合：790/1000，奖励：-243.77
# 回合：800/1000，奖励：-117.09
# 回合：810/1000，奖励：-117.30
# 回合：820/1000，奖励：-229.76
# 回合：830/1000，奖励：-338.30
# 回合：840/1000，奖励：-244.51
# 回合：850/1000，奖励：-121.25
# 回合：860/1000，奖励：-239.38
# 回合：870/1000，奖励：-121.01
# 回合：880/1000，奖励：-118.12
# 回合：890/1000，奖励：-361.90
# 回合：900/1000，奖励：-337.10
# 回合：910/1000，奖励：-119.13
# 回合：920/1000，奖励：-242.43
# 回合：930/1000，奖励：-119.12
# 回合：940/1000，奖励：-0.45
# 回合：950/1000，奖励：-232.89
# 回合：960/1000，奖励：-121.71
# 回合：970/1000，奖励：-352.01
# 回合：980/1000，奖励：-249.60
# 回合：990/1000，奖励：-127.04
# 回合：1000/1000，奖励：-227.94
# 完成训练！
# 开始测试！
# 回合：1/50，奖励：-122.45
# 回合：2/50，奖励：-331.39
# 回合：3/50，奖励：-0.60
# 回合：4/50，奖励：-293.33
# 回合：5/50，奖励：-0.73
# 回合：6/50，奖励：-336.28
# 回合：7/50，奖励：-119.85
# 回合：8/50，奖励：-116.73
# 回合：9/50，奖励：-117.25
# 回合：10/50，奖励：-230.02
# 回合：11/50，奖励：-125.13
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# 回合：12/50，奖励：-126.02
# 回合：13/50，奖励：-122.63
# 回合：14/50，奖励：-254.62
# 回合：15/50，奖励：-234.08
# 回合：16/50，奖励：-115.93
# 回合：17/50，奖励：-238.46
# 回合：18/50，奖励：-114.73
# 回合：19/50，奖励：-117.15
# 回合：20/50，奖励：-120.11
# 回合：21/50，奖励：-123.08
# 回合：22/50，奖励：-240.79
# 回合：23/50，奖励：-374.50
# 回合：24/50，奖励：-123.26
# 回合：25/50，奖励：-119.85
# 回合：26/50，奖励：-122.41
# 回合：27/50，奖励：-121.64
# 回合：28/50，奖励：-117.99
# 回合：29/50，奖励：-122.88
# 回合：30/50，奖励：-0.89
# 回合：31/50，奖励：-119.74
# 回合：32/50，奖励：-120.45
# 回合：33/50，奖励：-246.91
# 回合：34/50，奖励：-249.11
# 回合：35/50，奖励：-116.58
# 回合：36/50，奖励：-124.71
# 回合：37/50，奖励：-124.51
# 回合：38/50，奖励：-114.89
# 回合：39/50，奖励：-116.17
# 回合：40/50，奖励：-118.06
# 回合：41/50，奖励：-120.41
# 回合：42/50，奖励：-118.52
# 回合：43/50，奖励：-125.56
# 回合：44/50，奖励：-1.59
# 回合：45/50，奖励：-0.60
# 回合：46/50，奖励：-121.01
# 回合：47/50，奖励：-124.58
# 回合：48/50，奖励：-125.17
# 回合：49/50，奖励：-121.43
# 回合：50/50，奖励：-123.29
# 回合：51/50，奖励：-351.92
# 回合：52/50，奖励：-237.61
# 回合：53/50，奖励：-121.69
# 回合：54/50，奖励：-368.90
# 回合：55/50，奖励：-349.42
# 回合：56/50，奖励：-122.83
# 回合：57/50，奖励：-120.40
# 回合：58/50，奖励：-124.73
# 回合：59/50，奖励：-126.07
# 回合：60/50，奖励：-236.88
# 回合：61/50，奖励：-118.73
# 回合：62/50，奖励：-244.52
# 回合：63/50，奖励：-236.46
# 回合：64/50，奖励：-0.92
# 回合：65/50，奖励：-122.99
# 回合：66/50，奖励：-234.99
# 回合：67/50，奖励：-118.30
# 回合：68/50，奖励：-124.54
# 回合：69/50，奖励：-123.22
# 回合：70/50，奖励：-245.04
# 回合：71/50，奖励：-230.30
# 回合：72/50，奖励：-122.65
# 回合：73/50，奖励：-245.24
# 回合：74/50，奖励：-0.57
# 回合：75/50，奖励：-123.27
# 回合：76/50，奖励：-239.64
# 回合：77/50，奖励：-237.04
# 回合：78/50，奖励：-0.66
# 回合：79/50，奖励：-344.95
# 回合：80/50，奖励：-2.41
# 回合：81/50，奖励：-120.84
# 回合：82/50，奖励：-244.21
# 回合：83/50，奖励：-123.95
# 回合：84/50，奖励：-123.19
# 回合：85/50，奖励：-125.57
# 回合：86/50，奖励：-121.74
# 回合：87/50，奖励：-236.19
# 回合：88/50，奖励：-122.92
# 回合：89/50，奖励：-121.38
# 回合：90/50，奖励：-230.20
# 回合：91/50，奖励：-235.48
# 回合：92/50，奖励：-241.61
# 回合：93/50，奖励：-0.64
# 回合：94/50，奖励：-369.41
# 回合：95/50，奖励：-242.42
# 回合：96/50，奖励：-114.33
# 回合：97/50，奖励：-119.44
# 回合：98/50，奖励：-121.45
# 回合：99/50，奖励：-122.66
# 回合：100/50，奖励：-116.76
# 回合：101/50，奖励：-118.13
# 回合：102/50，奖励：-229.43
# 回合：103/50，奖励：-120.73
# 回合：104/50，奖励：-124.60
# 回合：105/50，奖励：-295.72
# 回合：106/50，奖励：-126.80
# 回合：107/50，奖励：-348.78
# 回合：108/50，奖励：-122.87
# 回合：109/50，奖励：-240.67
# 回合：110/50，奖励：-229.90
# 回合：111/50，奖励：-0.92
# 回合：112/50，奖励：-121.85
# 回合：113/50，奖励：-124.42
# 回合：114/50，奖励：-123.19
# 回合：115/50，奖励：-116.25
# 回合：116/50，奖励：-118.95
# 回合：117/50，奖励：-120.35
# 回合：118/50，奖励：-226.96
# 回合：119/50，奖励：-116.47
# 回合：120/50，奖励：-120.75
# 回合：121/50，奖励：-122.21
# 回合：122/50，奖励：-241.02
# 回合：123/50，奖励：-351.45
# 回合：124/50，奖励：-230.45
# 回合：125/50，奖励：-0.78
# 回合：126/50，奖励：-117.37
# 回合：127/50，奖励：-246.91
# 回合：128/50，奖励：-262.47
# 回合：129/50，奖励：-125.88
# 回合：130/50，奖励：-117.01
# 回合：131/50，奖励：-0.87
# 回合：132/50，奖励：-1.28
# 回合：133/50，奖励：-119.82
# 回合：134/50，奖励：-117.34
# 回合：135/50，奖励：-0.59
# 回合：136/50，奖励：-250.21
# 回合：137/50，奖励：-0.89
# 回合：138/50，奖励：-125.03
# 回合：139/50，奖励：-339.81
# 回合：140/50，奖励：-116.07
# 回合：141/50，奖励：-124.35
# 回合：142/50，奖励：-116.69
# 回合：143/50，奖励：-115.82
# 回合：144/50，奖励：-0.69
# 回合：145/50，奖励：-247.97
# 回合：146/50，奖励：-0.64
# 回合：147/50，奖励：-114.14
# 回合：148/50，奖励：-246.04
# 回合：149/50，奖励：-232.08
# 回合：150/50，奖励：-0.95
# 回合：151/50，奖励：-241.82
# 回合：152/50，奖励：-123.79
# 回合：153/50，奖励：-120.20
# 回合：154/50，奖励：-114.84
# 回合：155/50，奖励：-122.73
# 回合：156/50，奖励：-264.49
# 回合：157/50，奖励：-123.39
# 回合：158/50，奖励：-124.06
# 回合：159/50，奖励：-122.28
# 回合：160/50，奖励：-118.58
# 回合：161/50，奖励：-1.42
# 回合：162/50，奖励：-118.75
# 回合：163/50，奖励：-120.88
# 回合：164/50，奖励：-124.72
# 回合：165/50，奖励：-238.38
# 回合：166/50，奖励：-125.50
# 回合：167/50，奖励：-366.16
# 回合：168/50，奖励：-243.77
# 回合：169/50，奖励：-1.38
# 回合：170/50，奖励：-0.82
# 回合：171/50，奖励：-237.39
# 回合：172/50，奖励：-119.65
# 回合：173/50，奖励：-242.03
# 回合：174/50，奖励：-121.09
# 回合：175/50，奖励：-122.92
# 回合：176/50，奖励：-118.79
# 回合：177/50，奖励：-124.38
# 回合：178/50，奖励：-126.61
# 回合：179/50，奖励：-121.87
# 回合：180/50，奖励：-116.90
# 回合：181/50，奖励：-124.00
# 回合：182/50，奖励：-0.54
# 回合：183/50，奖励：-359.94
# 回合：184/50，奖励：-119.03
# 回合：185/50，奖励：-125.27
# 回合：186/50，奖励：-119.27
# 回合：187/50，奖励：-125.77
# 回合：188/50，奖励：-123.11
# 回合：189/50，奖励：-122.90
# 回合：190/50，奖励：-233.02
# 回合：191/50，奖励：-120.74
# 回合：192/50，奖励：-242.21
# 回合：193/50，奖励：-117.32
# 回合：194/50，奖励：-119.33
# 回合：195/50，奖励：-126.87
# 回合：196/50，奖励：-350.55
# 回合：197/50，奖励：-230.28
# 回合：198/50，奖励：-122.41
# 回合：199/50，奖励：-127.44
# 回合：200/50，奖励：-121.14
# 回合：201/50，奖励：-257.72
# 回合：202/50，奖励：-120.47
# 回合：203/50，奖励：-121.25
# 回合：204/50，奖励：-0.90
# 回合：205/50，奖励：-228.46
# 回合：206/50，奖励：-118.77
# 回合：207/50，奖励：-117.17
# 回合：208/50，奖励：-114.06
# 回合：209/50，奖励：-125.47
# 回合：210/50，奖励：-1.31
# 回合：211/50，奖励：-232.32
# 回合：212/50，奖励：-126.38
# 回合：213/50，奖励：-0.91
# 回合：214/50，奖励：-120.69
# 回合：215/50，奖励：-116.73
# 回合：216/50，奖励：-260.70
# 回合：217/50，奖励：-117.51
# 回合：218/50，奖励：-117.11
# 回合：219/50，奖励：-116.66
# 回合：220/50，奖励：-120.34
# 回合：221/50，奖励：-232.95
# 回合：222/50，奖励：-120.70
# 回合：223/50，奖励：-120.80
# 回合：224/50，奖励：-236.28
# 回合：225/50，奖励：-118.70
# 回合：226/50，奖励：-114.08
# 回合：227/50，奖励：-125.24
# 回合：228/50，奖励：-237.29
# 回合：229/50，奖励：-240.84
# 回合：230/50，奖励：-332.51
# 回合：231/50，奖励：-125.14
# 回合：232/50，奖励：-119.77
# 回合：233/50，奖励：-120.92
# 回合：234/50，奖励：-0.70
# 回合：235/50，奖励：-114.62
# 回合：236/50，奖励：-118.58
# 回合：237/50，奖励：-250.84
# 回合：238/50，奖励：-337.07
# 回合：239/50，奖励：-235.85
# 回合：240/50，奖励：-118.69
# 回合：241/50，奖励：-120.20
# 回合：242/50，奖励：-1.35
# 回合：243/50，奖励：-120.96
# 回合：244/50，奖励：-247.25
# 回合：245/50，奖励：-125.26
# 回合：246/50，奖励：-117.71
# 回合：247/50，奖励：-0.59
# 回合：248/50，奖励：-0.56
# 回合：249/50，奖励：-114.02
# 回合：250/50，奖励：-117.28
# 回合：251/50，奖励：-126.00
# 回合：252/50，奖励：-0.78
# 回合：253/50，奖励：-126.13
# 回合：254/50，奖励：-119.66
# 回合：255/50，奖励：-0.63
# 回合：256/50，奖励：-116.79
# 回合：257/50，奖励：-121.54
# 回合：258/50，奖励：-0.77
# 回合：259/50，奖励：-123.65
# 回合：260/50，奖励：-374.10
# 回合：261/50，奖励：-227.91
# 回合：262/50，奖励：-115.45
# 回合：263/50，奖励：-232.25
# 回合：264/50，奖励：-116.66
# 回合：265/50，奖励：-118.73
# 回合：266/50，奖励：-125.48
# 回合：267/50，奖励：-234.10
# 回合：268/50，奖励：-115.32
# 回合：269/50，奖励：-121.85
# 回合：270/50，奖励：-128.98
# 回合：271/50，奖励：-1.81
# 回合：272/50，奖励：-125.74
# 回合：273/50，奖励：-126.22
# 回合：274/50，奖励：-118.58
# 回合：275/50，奖励：-114.52
# 回合：276/50，奖励：-228.51
# 回合：277/50，奖励：-116.39
# 回合：278/50，奖励：-116.41
# 回合：279/50，奖励：-114.75
# 回合：280/50，奖励：-118.46
# 回合：281/50，奖励：-125.55
# 回合：282/50，奖励：-120.44
# 回合：283/50，奖励：-122.37
# 回合：284/50，奖励：-121.71
# 回合：285/50，奖励：-120.26
# 回合：286/50，奖励：-123.89
# 回合：287/50，奖励：-234.60
# 回合：288/50，奖励：-241.17
# 回合：289/50，奖励：-238.24
# 回合：290/50，奖励：-0.62
# 回合：291/50，奖励：-228.66
# 回合：292/50，奖励：-125.52
# 回合：293/50，奖励：-259.76
# 回合：294/50，奖励：-118.48
# 回合：295/50，奖励：-117.23
# 回合：296/50，奖励：-323.41
# 回合：297/50，奖励：-120.93
# 回合：298/50，奖励：-345.21
# 回合：299/50，奖励：-320.20
# 回合：300/50，奖励：-121.30
# 回合：301/50，奖励：-125.21
# 回合：302/50，奖励：-118.67
# 回合：303/50，奖励：-117.02
# 回合：304/50，奖励：-121.87
# 回合：305/50，奖励：-1.74
# 回合：306/50，奖励：-2.18
# 回合：307/50，奖励：-125.00
# 回合：308/50，奖励：-114.89
# 回合：309/50，奖励：-233.72
# 回合：310/50，奖励：-118.99
# 回合：311/50，奖励：-125.19
# 回合：312/50，奖励：-1.37
# 回合：313/50，奖励：-126.88
# 回合：314/50，奖励：-232.39
# 回合：315/50，奖励：-116.03
# 回合：316/50，奖励：-236.07
# 回合：317/50，奖励：-114.27
# 回合：318/50，奖励：-122.05
# 回合：319/50，奖励：-127.02
# 回合：320/50，奖励：-115.19
# 回合：321/50，奖励：-229.72
# 回合：322/50，奖励：-117.63
# 回合：323/50，奖励：-123.54
# 回合：324/50，奖励：-118.77
# 回合：325/50，奖励：-126.18
# 回合：326/50，奖励：-118.73
# 回合：327/50，奖励：-233.04
# 回合：328/50，奖励：-229.03
# 回合：329/50，奖励：-122.88
# 回合：330/50，奖励：-231.40
# 回合：331/50，奖励：-1.20
# 回合：332/50，奖励：-115.72
# 回合：333/50，奖励：-125.80
# 回合：334/50，奖励：-115.63
# 回合：335/50，奖励：-118.75
# 回合：336/50，奖励：-232.81
# 回合：337/50，奖励：-322.09
# 回合：338/50，奖励：-126.25
# 回合：339/50，奖励：-126.06
# 回合：340/50，奖励：-117.79
# 回合：341/50，奖励：-115.48
# 回合：342/50，奖励：-352.00
# 回合：343/50，奖励：-114.46
# 回合：344/50，奖励：-114.04
# 回合：345/50，奖励：-115.80
# 回合：346/50，奖励：-116.71
# 回合：347/50，奖励：-245.15
# 回合：348/50，奖励：-118.08
# 回合：349/50，奖励：-125.15
# 回合：350/50，奖励：-123.46
# 回合：351/50，奖励：-118.28
# 回合：352/50，奖励：-120.99
# 回合：353/50，奖励：-118.46
# 回合：354/50，奖励：-126.54
# 回合：355/50，奖励：-338.64
# 回合：356/50，奖励：-235.87
# 回合：357/50，奖励：-232.01
# 回合：358/50，奖励：-237.23
# 回合：359/50，奖励：-1.03
# 回合：360/50，奖励：-126.40
# 回合：361/50，奖励：-116.51
# 回合：362/50，奖励：-118.84
# 回合：363/50，奖励：-118.68
# 回合：364/50，奖励：-125.59
# 回合：365/50，奖励：-117.53
# 回合：366/50，奖励：-239.75
# 回合：367/50，奖励：-1.31
# 回合：368/50，奖励：-0.85
# 回合：369/50，奖励：-0.58
# 回合：370/50，奖励：-235.38
# 回合：371/50，奖励：-356.37
# 回合：372/50，奖励：-226.86
# 回合：373/50，奖励：-235.38
# 回合：374/50，奖励：-122.43
# 回合：375/50，奖励：-338.88
# 回合：376/50，奖励：-0.61
# 回合：377/50，奖励：-254.96
# 回合：378/50，奖励：-240.31
# 回合：379/50，奖励：-349.79
# 回合：380/50，奖励：-126.50
# 回合：381/50，奖励：-227.85
# 回合：382/50，奖励：-255.80
# 回合：383/50，奖励：-222.90
# 回合：384/50，奖励：-231.31
# 回合：385/50，奖励：-118.43
# 回合：386/50，奖励：-124.84
# 回合：387/50，奖励：-115.81
# 回合：388/50，奖励：-121.00
# 回合：389/50，奖励：-119.43
# 回合：390/50，奖励：-228.46
# 回合：391/50，奖励：-116.17
# 回合：392/50，奖励：-236.45
# 回合：393/50，奖励：-118.76
# 回合：394/50，奖励：-341.92
# 回合：395/50，奖励：-120.28
# 回合：396/50，奖励：-119.99
# 回合：397/50，奖励：-117.07
# 回合：398/50，奖励：-118.48
# 回合：399/50，奖励：-126.10
# 回合：400/50，奖励：-239.22
# 回合：401/50，奖励：-0.81
# 回合：402/50，奖励：-115.53
# 回合：403/50，奖励：-117.23
# 回合：404/50，奖励：-349.69
# 回合：405/50，奖励：-350.77
# 回合：406/50，奖励：-0.65
# 回合：407/50，奖励：-243.52
# 回合：408/50，奖励：-251.37
# 回合：409/50，奖励：-237.12
# 回合：410/50，奖励：-114.30
# 回合：411/50，奖励：-238.20
# 回合：412/50，奖励：-122.55
# 回合：413/50，奖励：-336.66
# 回合：414/50，奖励：-116.34
# 回合：415/50，奖励：-353.18
# 回合：416/50，奖励：-126.30
# 回合：417/50，奖励：-122.33
# 回合：418/50，奖励：-0.82
# 回合：419/50，奖励：-127.00
# 回合：420/50，奖励：-117.58
# 回合：421/50，奖励：-123.37
# 回合：422/50，奖励：-119.95
# 回合：423/50，奖励：-122.78
# 回合：424/50，奖励：-117.65
# 回合：425/50，奖励：-115.34
# 回合：426/50，奖励：-126.00
# 回合：427/50，奖励：-230.92
# 回合：428/50，奖励：-118.77
# 回合：429/50，奖励：-120.03
# 回合：430/50，奖励：-240.72
# 回合：431/50，奖励：-236.71
# 回合：432/50，奖励：-115.12
# 回合：433/50，奖励：-125.10
# 回合：434/50，奖励：-238.91
# 回合：435/50，奖励：-311.09
# 回合：436/50，奖励：-316.23
# 回合：437/50，奖励：-244.69
# 回合：438/50，奖励：-238.09
# 回合：439/50，奖励：-116.85
# 回合：440/50，奖励：-125.18
# 回合：441/50，奖励：-123.90
# 回合：442/50，奖励：-123.18
# 回合：443/50，奖励：-116.70
# 回合：444/50，奖励：-123.00
# 回合：445/50，奖励：-318.27
# 回合：446/50，奖励：-370.20
# 回合：447/50，奖励：-244.99
# 回合：448/50，奖励：-124.20
# 回合：449/50，奖励：-123.35
# 回合：450/50，奖励：-117.79
# 回合：451/50，奖励：-125.50
# 回合：452/50，奖励：-350.64
# 回合：453/50，奖励：-124.31
# 回合：454/50，奖励：-116.38
# 回合：455/50，奖励：-360.07
# 回合：456/50，奖励：-120.07
# 回合：457/50，奖励：-234.40
# 回合：458/50，奖励：-120.25
# 回合：459/50，奖励：-125.79
# 回合：460/50，奖励：-363.79
# 回合：461/50，奖励：-250.70
# 回合：462/50，奖励：-124.27
# 回合：463/50，奖励：-126.33
# 回合：464/50，奖励：-123.89
# 回合：465/50，奖励：-341.00
# 回合：466/50，奖励：-115.79
# 回合：467/50，奖励：-118.83
# 回合：468/50，奖励：-119.17
# 回合：469/50，奖励：-122.15
# 回合：470/50，奖励：-122.14
# 回合：471/50，奖励：-243.74
# 回合：472/50，奖励：-120.54
# 回合：473/50，奖励：-228.22
# 回合：474/50，奖励：-245.34
# 回合：475/50，奖励：-120.57
# 回合：476/50，奖励：-124.61
# 回合：477/50，奖励：-233.44
# 回合：478/50，奖励：-0.58
# 回合：479/50，奖励：-228.82
# 回合：480/50，奖励：-234.75
# 回合：481/50，奖励：-239.65
# 回合：482/50，奖励：-243.32
# 回合：483/50，奖励：-237.15
# 回合：484/50，奖励：-118.94
# 回合：485/50，奖励：-118.66
# 回合：486/50，奖励：-0.70
# 回合：487/50，奖励：-244.70
# 回合：488/50，奖励：-0.58
# 回合：489/50，奖励：-118.06
# 回合：490/50，奖励：-125.18
# 回合：491/50，奖励：-0.65
# 回合：492/50，奖励：-125.36
# 回合：493/50，奖励：-365.70
# 回合：494/50，奖励：-122.94
# 回合：495/50，奖励：-1.28
# 回合：496/50，奖励：-121.02
# 回合：497/50，奖励：-124.53
# 回合：498/50，奖励：-229.01
# 回合：499/50，奖励：-118.81
# 回合：500/50，奖励：-252.16
# 回合：501/50，奖励：-0.62
# 回合：502/50，奖励：-1.67
# 回合：503/50，奖励：-125.68
# 回合：504/50，奖励：-124.15
# 回合：505/50，奖励：-117.62
# 回合：506/50，奖励：-0.63
# 回合：507/50，奖励：-341.44
# 回合：508/50，奖励：-118.70
# 回合：509/50，奖励：-236.40
# 回合：510/50，奖励：-0.75
# 回合：511/50，奖励：-116.42
# 回合：512/50，奖励：-118.92
# 回合：513/50，奖励：-122.08
# 回合：514/50，奖励：-358.79
# 回合：515/50，奖励：-125.07
# 回合：516/50，奖励：-122.38
# 回合：517/50，奖励：-120.24
# 回合：518/50，奖励：-124.05
# 回合：519/50，奖励：-124.05
# 回合：520/50，奖励：-115.23
# 回合：521/50，奖励：-123.85
# 回合：522/50，奖励：-119.42
# 回合：523/50，奖励：-347.54
# 回合：524/50，奖励：-121.24
# 回合：525/50，奖励：-339.58
# 回合：526/50，奖励：-119.78
# 回合：527/50，奖励：-118.40
# 回合：528/50，奖励：-115.42
# 回合：529/50，奖励：-119.64
# 回合：530/50，奖励：-123.15
# 回合：531/50，奖励：-236.22
# 回合：532/50，奖励：-240.33
# 回合：533/50，奖励：-311.14
# 回合：534/50，奖励：-0.90
# 回合：535/50，奖励：-115.74
# 回合：536/50，奖励：-114.70
# 回合：537/50，奖励：-240.81
# 回合：538/50，奖励：-118.13
# 回合：539/50，奖励：-118.55
# 回合：540/50，奖励：-122.83
# 回合：541/50，奖励：-117.70
# 回合：542/50，奖励：-367.61
# 回合：543/50，奖励：-330.02
# 回合：544/50，奖励：-0.63
# 回合：545/50，奖励：-119.56
# 回合：546/50，奖励：-0.65
# 回合：547/50，奖励：-123.44
# 回合：548/50，奖励：-117.84
# 回合：549/50，奖励：-121.58
# 回合：550/50，奖励：-241.01
# 回合：551/50，奖励：-121.42
# 回合：552/50，奖励：-246.65
# 回合：553/50，奖励：-116.43
# 回合：554/50，奖励：-118.76
# 回合：555/50，奖励：-116.75
# 回合：556/50，奖励：-231.38
# 回合：557/50，奖励：-228.39
# 回合：558/50，奖励：-122.06
# 回合：559/50，奖励：-357.70
# 回合：560/50，奖励：-122.59
# 回合：561/50，奖励：-235.77
# 回合：562/50，奖励：-256.89
# 回合：563/50，奖励：-251.30
# 回合：564/50，奖励：-125.51
# 回合：565/50，奖励：-115.66
# 回合：566/50，奖励：-249.09
# 回合：567/50，奖励：-116.43
# 回合：568/50，奖励：-120.57
# 回合：569/50，奖励：-230.94
# 回合：570/50，奖励：-119.22
# 回合：571/50，奖励：-114.50
# 回合：572/50，奖励：-313.80
# 回合：573/50，奖励：-125.55
# 回合：574/50，奖励：-122.59
# 回合：575/50，奖励：-356.01
# 回合：576/50，奖励：-229.58
# 回合：577/50，奖励：-239.75
# 回合：578/50，奖励：-125.20
# 回合：579/50，奖励：-119.88
# 回合：580/50，奖励：-243.13
# 回合：581/50，奖励：-122.97
# 回合：582/50，奖励：-0.66
# 回合：583/50，奖励：-122.08
# 回合：584/50，奖励：-124.60
# 回合：585/50，奖励：-121.23
# 回合：586/50，奖励：-233.72
# 回合：587/50，奖励：-238.41
# 回合：588/50，奖励：-124.61
# 回合：589/50，奖励：-122.28
# 回合：590/50，奖励：-2.03
# 回合：591/50，奖励：-125.61
# 回合：592/50，奖励：-119.67
# 回合：593/50，奖励：-1.60
# 回合：594/50，奖励：-236.91
# 回合：595/50，奖励：-320.35
# 回合：596/50，奖励：-120.53
# 回合：597/50，奖励：-241.93
# 回合：598/50，奖励：-122.46
# 回合：599/50，奖励：-344.06
# 回合：600/50，奖励：-296.15
# 回合：601/50，奖励：-248.28
# 回合：602/50，奖励：-125.82
# 回合：603/50，奖励：-120.20
# 回合：604/50，奖励：-237.09
# 回合：605/50，奖励：-252.69
# 回合：606/50，奖励：-123.71
# 回合：607/50，奖励：-116.42
# 回合：608/50，奖励：-114.98
# 回合：609/50，奖励：-380.17
# 回合：610/50，奖励：-244.78
# 回合：611/50，奖励：-235.76
# 回合：612/50，奖励：-0.54
# 回合：613/50，奖励：-116.77
# 回合：614/50，奖励：-2.83
# 回合：615/50，奖励：-236.52
# 回合：616/50，奖励：-232.40
# 回合：617/50，奖励：-229.34
# 回合：618/50，奖励：-126.90
# 回合：619/50，奖励：-229.05
# 回合：620/50，奖励：-121.27
# 回合：621/50，奖励：-120.94
# 回合：622/50，奖励：-237.44
# 回合：623/50，奖励：-125.28
# 回合：624/50，奖励：-233.93
# 回合：625/50，奖励：-350.47
# 回合：626/50，奖励：-237.27
# 回合：627/50，奖励：-0.95
# 回合：628/50，奖励：-236.36
# 回合：629/50，奖励：-236.32
# 回合：630/50，奖励：-118.70
# 回合：631/50，奖励：-241.80
# 回合：632/50，奖励：-238.26
# 回合：633/50，奖励：-232.80
# 回合：634/50，奖励：-125.53
# 回合：635/50，奖励：-0.77
# 回合：636/50，奖励：-117.55
# 回合：637/50，奖励：-253.10
# 回合：638/50，奖励：-253.67
# 回合：639/50，奖励：-124.38
# 回合：640/50，奖励：-235.55
# 回合：641/50，奖励：-229.27
# 回合：642/50，奖励：-123.03
# 回合：643/50，奖励：-123.20
# 回合：644/50，奖励：-122.08
# 回合：645/50，奖励：-346.85
# 回合：646/50，奖励：-230.66
# 回合：647/50，奖励：-122.14
# 回合：648/50，奖励：-0.55
# 回合：649/50，奖励：-124.37
# 回合：650/50，奖励：-119.49
# 回合：651/50，奖励：-244.48
# 回合：652/50，奖励：-122.59
# 回合：653/50，奖励：-232.04
# 回合：654/50，奖励：-121.05
# 回合：655/50，奖励：-243.38
# 回合：656/50，奖励：-0.68
# 回合：657/50，奖励：-117.45
# 回合：658/50，奖励：-125.66
# 回合：659/50，奖励：-118.29
# 回合：660/50，奖励：-118.18
# 回合：661/50，奖励：-231.10
# 回合：662/50，奖励：-117.89
# 回合：663/50，奖励：-123.57
# 回合：664/50，奖励：-122.50
# 回合：665/50，奖励：-240.33
# 回合：666/50，奖励：-116.84
# 回合：667/50，奖励：-122.32
# 回合：668/50，奖励：-1.03
# 回合：669/50，奖励：-123.73
# 回合：670/50，奖励：-232.07
# 回合：671/50，奖励：-244.61
# 回合：672/50，奖励：-1.82
# 回合：673/50，奖励：-124.49
# 回合：674/50，奖励：-234.44
# 回合：675/50，奖励：-116.76
# 回合：676/50，奖励：-241.28
# 回合：677/50，奖励：-116.93
# 回合：678/50，奖励：-121.18
# 回合：679/50，奖励：-117.74
# 回合：680/50，奖励：-337.24
# 回合：681/50，奖励：-376.64
# 回合：682/50，奖励：-339.52
# 回合：683/50，奖励：-122.87
# 回合：684/50，奖励：-122.73
# 回合：685/50，奖励：-116.83
# 回合：686/50，奖励：-124.74
# 回合：687/50，奖励：-0.85
# 回合：688/50，奖励：-124.13
# 回合：689/50，奖励：-116.81
# 回合：690/50，奖励：-126.24
# 回合：691/50，奖励：-116.80
# 回合：692/50，奖励：-121.52
# 回合：693/50，奖励：-228.90
# 回合：694/50，奖励：-1.06
# 回合：695/50，奖励：-257.34
# 回合：696/50，奖励：-122.31
# 回合：697/50，奖励：-123.47
# 回合：698/50，奖励：-118.34
# 回合：699/50，奖励：-116.07
# 回合：700/50，奖励：-120.80
# 回合：701/50，奖励：-119.62
# 回合：702/50，奖励：-308.14
# 回合：703/50，奖励：-115.01
# 回合：704/50，奖励：-119.55
# 回合：705/50，奖励：-0.91
# 回合：706/50，奖励：-252.89
# 回合：707/50，奖励：-241.87
# 回合：708/50，奖励：-117.30
# 回合：709/50，奖励：-0.66
# 回合：710/50，奖励：-233.36
# 回合：711/50，奖励：-2.03
# 回合：712/50，奖励：-123.64
# 回合：713/50，奖励：-114.99
# 回合：714/50，奖励：-2.09
# 回合：715/50，奖励：-373.63
# 回合：716/50，奖励：-128.41
# 回合：717/50，奖励：-121.90
# 回合：718/50，奖励：-114.93
# 回合：719/50，奖励：-117.88
# 回合：720/50，奖励：-120.47
# 回合：721/50，奖励：-116.65
# 回合：722/50，奖励：-121.01
# 回合：723/50，奖励：-122.63
# 回合：724/50，奖励：-121.54
# 回合：725/50，奖励：-237.78
# 回合：726/50，奖励：-123.79
# 回合：727/50，奖励：-366.93
# 回合：728/50，奖励：-0.74
# 回合：729/50，奖励：-0.74
# 回合：730/50，奖励：-232.51
# 回合：731/50，奖励：-122.26
# 回合：732/50，奖励：-120.17
# 回合：733/50，奖励：-121.54
# 回合：734/50，奖励：-120.71
# 回合：735/50，奖励：-248.64
# 回合：736/50，奖励：-118.92
# 回合：737/50，奖励：-239.75
# 回合：738/50，奖励：-235.24
# 回合：739/50，奖励：-121.90
# 回合：740/50，奖励：-124.88
# 回合：741/50，奖励：-241.84
# 回合：742/50，奖励：-116.43
# 回合：743/50，奖励：-120.17
# 回合：744/50，奖励：-124.75
# 回合：745/50，奖励：-351.35
# 回合：746/50，奖励：-229.30
# 回合：747/50，奖励：-238.90
# 回合：748/50，奖励：-0.55
# 回合：749/50，奖励：-1.07
# 回合：750/50，奖励：-118.17
# 回合：751/50，奖励：-360.25
# 回合：752/50，奖励：-125.36
# 回合：753/50，奖励：-119.10
# 回合：754/50，奖励：-118.88
# 回合：755/50，奖励：-119.04
# 回合：756/50，奖励：-125.10
# 回合：757/50，奖励：-116.96
# 回合：758/50，奖励：-237.46
# 回合：759/50，奖励：-233.33
# 回合：760/50，奖励：-117.28
# 回合：761/50，奖励：-239.80
# 回合：762/50，奖励：-1.65
# 回合：763/50，奖励：-125.07
# 回合：764/50，奖励：-125.90
# 回合：765/50，奖励：-116.43
# 回合：766/50，奖励：-122.34
# 回合：767/50，奖励：-273.88
# 回合：768/50，奖励：-122.82
# 回合：769/50，奖励：-235.00
# 回合：770/50，奖励：-123.06
# 回合：771/50，奖励：-253.75
# 回合：772/50，奖励：-118.34
# 回合：773/50，奖励：-238.37
# 回合：774/50，奖励：-117.23
# 回合：775/50，奖励：-229.71
# 回合：776/50，奖励：-120.88
# 回合：777/50，奖励：-119.82
# 回合：778/50，奖励：-0.58
# 回合：779/50，奖励：-122.75
# 回合：780/50，奖励：-121.08
# 回合：781/50，奖励：-245.20
# 回合：782/50，奖励：-246.60
# 回合：783/50，奖励：-237.96
# 回合：784/50，奖励：-231.79
# 回合：785/50，奖励：-125.60
# 回合：786/50，奖励：-228.79
# 回合：787/50，奖励：-115.64
# 回合：788/50，奖励：-119.08
# 回合：789/50，奖励：-122.19
# 回合：790/50，奖励：-124.96
# 回合：791/50，奖励：-124.44
# 回合：792/50，奖励：-122.68
# 回合：793/50，奖励：-327.46
# 回合：794/50，奖励：-1.05
# 回合：795/50，奖励：-120.54
# 回合：796/50，奖励：-229.96
# 回合：797/50，奖励：-235.69
# 回合：798/50，奖励：-0.70
# 回合：799/50，奖励：-234.39
# 回合：800/50，奖励：-241.59
# 回合：801/50，奖励：-238.24
# 回合：802/50，奖励：-0.57
# 回合：803/50，奖励：-233.57
# 回合：804/50，奖励：-247.87
# 回合：805/50，奖励：-119.69
# 回合：806/50，奖励：-0.66
# 回合：807/50，奖励：-119.21
# 回合：808/50，奖励：-119.91
# 回合：809/50，奖励：-124.45
# 回合：810/50，奖励：-123.86
# 回合：811/50，奖励：-121.85
# 回合：812/50，奖励：-126.26
# 回合：813/50，奖励：-122.50
# 回合：814/50，奖励：-117.01
# 回合：815/50，奖励：-232.55
# 回合：816/50，奖励：-123.14
# 回合：817/50，奖励：-1.08
# 回合：818/50，奖励：-238.78
# 回合：819/50，奖励：-0.73
# 回合：820/50，奖励：-231.12
# 回合：821/50，奖励：-355.17
# 回合：822/50，奖励：-119.93
# 回合：823/50，奖励：-116.80
# 回合：824/50，奖励：-118.49
# 回合：825/50，奖励：-114.97
# 回合：826/50，奖励：-0.69
# 回合：827/50，奖励：-123.45
# 回合：828/50，奖励：-230.94
# 回合：829/50，奖励：-377.33
# 回合：830/50，奖励：-118.41
# 回合：831/50，奖励：-120.54
# 回合：832/50，奖励：-359.05
# 回合：833/50，奖励：-125.82
# 回合：834/50，奖励：-120.46
# 回合：835/50，奖励：-125.43
# 回合：836/50，奖励：-0.60
# 回合：837/50，奖励：-123.31
# 回合：838/50，奖励：-233.36
# 回合：839/50，奖励：-124.66
# 回合：840/50，奖励：-114.98
# 回合：841/50，奖励：-117.06
# 回合：842/50，奖励：-122.06
# 回合：843/50，奖励：-231.65
# 回合：844/50，奖励：-126.63
# 回合：845/50，奖励：-244.75
# 回合：846/50，奖励：-119.40
# 回合：847/50，奖励：-126.46
# 回合：848/50，奖励：-353.03
# 回合：849/50，奖励：-231.73
# 回合：850/50，奖励：-121.48
# 回合：851/50，奖励：-124.90
# 回合：852/50，奖励：-122.24
# 回合：853/50，奖励：-121.01
# 回合：854/50，奖励：-118.33
# 回合：855/50，奖励：-229.13
# 回合：856/50，奖励：-118.93
# 回合：857/50，奖励：-125.58
# 回合：858/50，奖励：-235.99
# 回合：859/50，奖励：-249.04
# 回合：860/50，奖励：-126.61
# 回合：861/50，奖励：-121.34
# 回合：862/50，奖励：-116.86
# 回合：863/50，奖励：-1.87
# 回合：864/50，奖励：-237.71
# 回合：865/50，奖励：-243.88
# 回合：866/50，奖励：-126.37
# 回合：867/50，奖励：-243.23
# 回合：868/50，奖励：-123.48
# 回合：869/50，奖励：-350.74
# 回合：870/50，奖励：-240.67
# 回合：871/50，奖励：-115.22
# 回合：872/50，奖励：-224.16
# 回合：873/50，奖励：-122.50
# 回合：874/50，奖励：-125.38
# 回合：875/50，奖励：-115.02
# 回合：876/50，奖励：-124.26
# 回合：877/50，奖励：-239.38
# 回合：878/50，奖励：-231.39
# 回合：879/50，奖励：-242.21
# 回合：880/50，奖励：-124.49
# 回合：881/50，奖励：-123.18
# 回合：882/50，奖励：-0.67
# 回合：883/50，奖励：-122.15
# 回合：884/50，奖励：-256.48
# 回合：885/50，奖励：-360.93
# 回合：886/50，奖励：-233.25
# 回合：887/50，奖励：-117.77
# 回合：888/50，奖励：-0.73
# 回合：889/50，奖励：-120.68
# 回合：890/50，奖励：-117.91
# 回合：891/50，奖励：-232.78
# 回合：892/50，奖励：-274.67
# 回合：893/50，奖励：-122.32
# 回合：894/50，奖励：-370.79
# 回合：895/50，奖励：-125.47
# 回合：896/50，奖励：-119.03
# 回合：897/50，奖励：-377.51
# 回合：898/50，奖励：-233.99
# 回合：899/50，奖励：-252.03
# 回合：900/50，奖励：-122.85
# 回合：901/50，奖励：-124.85
# 回合：902/50，奖励：-228.12
# 回合：903/50，奖励：-121.91
# 回合：904/50，奖励：-238.86
# 回合：905/50，奖励：-1.76
# 回合：906/50，奖励：-0.70
# 回合：907/50，奖励：-126.77
# 回合：908/50，奖励：-117.73
# 回合：909/50，奖励：-0.86
# 回合：910/50，奖励：-117.92
# 回合：911/50，奖励：-235.18
# 回合：912/50，奖励：-0.71
# 回合：913/50，奖励：-0.85
# 回合：914/50，奖励：-0.94
# 回合：915/50，奖励：-123.75
# 回合：916/50，奖励：-126.38
# 回合：917/50，奖励：-235.76
# 回合：918/50，奖励：-356.03
# 回合：919/50，奖励：-124.93
# 回合：920/50，奖励：-230.57
# 回合：921/50，奖励：-119.49
# 回合：922/50，奖励：-122.18
# 回合：923/50，奖励：-117.53
# 回合：924/50，奖励：-237.61
# 回合：925/50，奖励：-125.29
# 回合：926/50，奖励：-230.79
# 回合：927/50，奖励：-123.37
# 回合：928/50，奖励：-118.06
# 回合：929/50，奖励：-117.76
# 回合：930/50，奖励：-124.13
# 回合：931/50，奖励：-116.46
# 回合：932/50，奖励：-117.27
# 回合：933/50，奖励：-121.48
# 回合：934/50，奖励：-116.64
# 回合：935/50，奖励：-230.68
# 回合：936/50，奖励：-242.61
# 回合：937/50，奖励：-120.46
# 回合：938/50，奖励：-122.20
# 回合：939/50，奖励：-117.06
# 回合：940/50，奖励：-238.40
# 回合：941/50，奖励：-124.79
# 回合：942/50，奖励：-247.39
# 回合：943/50，奖励：-119.56
# 回合：944/50，奖励：-118.02
# 回合：945/50，奖励：-124.71
# 回合：946/50，奖励：-116.79
# 回合：947/50，奖励：-117.21
# 回合：948/50，奖励：-120.76
# 回合：949/50，奖励：-366.73
# 回合：950/50，奖励：-124.38
# 回合：951/50，奖励：-117.28
# 回合：952/50，奖励：-244.27
# 回合：953/50，奖励：-237.43
# 回合：954/50，奖励：-240.76
# 回合：955/50，奖励：-123.20
# 回合：956/50，奖励：-118.26
# 回合：957/50，奖励：-118.19
# 回合：958/50，奖励：-126.13
# 回合：959/50，奖励：-1.07
# 回合：960/50，奖励：-116.80
# 回合：961/50，奖励：-125.40
# 回合：962/50，奖励：-125.72
# 回合：963/50，奖励：-241.23
# 回合：964/50，奖励：-240.71
# 回合：965/50，奖励：-123.99
# 回合：966/50，奖励：-243.51
# 回合：967/50，奖励：-372.98
# 回合：968/50，奖励：-234.33
# 回合：969/50，奖励：-122.85
# 回合：970/50，奖励：-117.90
# 回合：971/50，奖励：-233.01
# 回合：972/50，奖励：-123.22
# 回合：973/50，奖励：-126.51
# 回合：974/50，奖励：-120.82
# 回合：975/50，奖励：-115.87
# 回合：976/50，奖励：-116.11
# 回合：977/50，奖励：-243.48
# 回合：978/50，奖励：-118.76
# 回合：979/50，奖励：-125.54
# 回合：980/50，奖励：-228.80
# 回合：981/50，奖励：-0.67
# 回合：982/50，奖励：-120.22
# 回合：983/50，奖励：-124.03
# 回合：984/50，奖励：-245.18
# 回合：985/50，奖励：-116.77
# 回合：986/50，奖励：-120.52
# 回合：987/50，奖励：-0.56
# 回合：988/50，奖励：-236.66
# 回合：989/50，奖励：-114.63
# 回合：990/50，奖励：-238.35
# 回合：991/50，奖励：-122.97
# 回合：992/50，奖励：-124.73
# 回合：993/50，奖励：-121.68
# 回合：994/50，奖励：-116.27
# 回合：995/50，奖励：-125.04
# 回合：996/50，奖励：-238.32
# 回合：997/50，奖励：-126.21
# 回合：998/50，奖励：-235.67
# 回合：999/50，奖励：-118.03
# 回合：1000/50，奖励：-240.11
# 完成测试！
